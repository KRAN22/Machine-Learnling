# %% [markdown]
# # Importing the  Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train_data = pd.read_csv(r"C:\Users\kd67152\Desktop\Datasets\train.csv") 
train_data.head()
# Out:
#    id   timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0   1  2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 1   2  2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 2   3  2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 3   4  2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 4   5  2011-09-05       77     77.0    4.0        NaN       NaN         NaN
#
#    num_room  kitch_sq  ...  cafe_count_5000_price_2500  \
# 0       NaN       NaN  ...                           9
# 1       NaN       NaN  ...                          15
# 2       NaN       NaN  ...                          10
# 3       NaN       NaN  ...                          11
# 4       NaN       NaN  ...                         319
#
#   cafe_count_5000_price_4000 cafe_count_5000_price_high  \
# 0                          4                          0
# 1                          3                          0
# 2                          3                          0
# 3                          2                          1
# 4                        108                         17
#
#    big_church_count_5000  church_count_5000  mosque_count_5000  \
# 0                     13                 22                  1
# 1                     15                 29                  1
# 2                     11                 27                  0
# 3                      4                  4                  0
# 4                    135                236                  2
#
#    leisure_count_5000  sport_count_5000  market_count_5000  price_doc
# 0                   0                52                  4    5850000
# 1                  10                66                 14    6000000
# 2                   4                67                 10    5700000
# 3                   0                26                  3   13100000
# 4                  91               195                 14   16331452
#
# [5 rows x 292 columns]

# %%
train_data.shape
# Out:
# (30471, 292)

# %%
train_data["timestamp"] = train_data["timestamp"].apply(lambda x: x[:4]).astype("float64")
train_data.head()
# Out:
#    id  timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0   1     2011.0       43     27.0    4.0        NaN       NaN         NaN
# 1   2     2011.0       34     19.0    3.0        NaN       NaN         NaN
# 2   3     2011.0       43     29.0    2.0        NaN       NaN         NaN
# 3   4     2011.0       89     50.0    9.0        NaN       NaN         NaN
# 4   5     2011.0       77     77.0    4.0        NaN       NaN         NaN
#
#    num_room  kitch_sq  ...  cafe_count_5000_price_2500  \
# 0       NaN       NaN  ...                           9
# 1       NaN       NaN  ...                          15
# 2       NaN       NaN  ...                          10
# 3       NaN       NaN  ...                          11
# 4       NaN       NaN  ...                         319
#
#   cafe_count_5000_price_4000 cafe_count_5000_price_high  \
# 0                          4                          0
# 1                          3                          0
# 2                          3                          0
# 3                          2                          1
# 4                        108                         17
#
#    big_church_count_5000  church_count_5000  mosque_count_5000  \
# 0                     13                 22                  1
# 1                     15                 29                  1
# 2                     11                 27                  0
# 3                      4                  4                  0
# 4                    135                236                  2
#
#    leisure_count_5000  sport_count_5000  market_count_5000  price_doc
# 0                   0                52                  4    5850000
# 1                  10                66                 14    6000000
# 2                   4                67                 10    5700000
# 3                   0                26                  3   13100000
# 4                  91               195                 14   16331452
#
# [5 rows x 292 columns]

# %%
train_data["build_year"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # Feature Engineering

# %%
train_data["build_age"] = train_data["timestamp"] - train_data["build_year"]
train_data["build_age"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 30466    40.0
# 30467    80.0
# 30468     NaN
# 30469    12.0
# 30470    47.0
# Name: build_age, Length: 30471, dtype: float64

# %% [markdown]
# # Selected columns

# %%
columns = ["oil_chemistry_km","big_church_km","water_km","park_km","power_transmission_line_km","radiation_km","cemetery_km","kindergarten_km","healthcare_centers_raion","full_all","full_sq","school_km","zd_vokzaly_avto_km","trc_count_1500","thermal_power_plant_km","incineration_km","green_zone_km","trc_count_1000","metro_km_walk","big_market_km"]
len(columns)
# Out:
# 20

# %% [markdown]
# # Create a dataFrame with selected columns

# %%
dataFrame = pd.DataFrame(train_data[columns])
dataFrame["price_doc"] = train_data["price_doc"]
dataFrame.head()
# Out:
#    oil_chemistry_km  big_church_km  water_km   park_km  \
# 0         18.152338       0.625783  0.992631  2.158587
# 1          9.034642       0.967821  0.698081  0.550690
# 2          5.777394       3.178751  0.468265  0.374848
# 3         27.667863       1.031777  1.200336  0.078090
# 4          6.515857       0.378756  0.820294  0.258289
#
#    power_transmission_line_km  radiation_km  cemetery_km  kindergarten_km  \
# 0                    1.062513      1.210027     1.804127         0.145700
# 1                    1.246149      2.724295     4.655004         0.147754
# 2                    1.602183      0.772216     3.381083         0.049102
# 3                    1.767612      6.348716     2.017080         0.179441
# 4                    3.632640      1.638318     2.936581         0.247901
#
#    healthcare_centers_raion  full_all  ...  school_km  zd_vokzaly_avto_km  \
# 0                         1     86206  ...   0.177975           14.231961
# 1                         1     76284  ...   0.273345            9.242586
# 2                         1    101982  ...   0.158072            9.540544
# 3                         1     21155  ...   0.236455           17.478380
# 4                         4     28179  ...   0.376838            1.595898
#
#    trc_count_1500  thermal_power_plant_km  incineration_km  green_zone_km  \
# 0               9                5.814135         3.633334       0.600973
# 1               7                3.419574         8.648587       0.065321
# 2               1                3.682455        11.996480       0.453172
# 3               7               11.178333        14.317640       0.106125
# 4               9                4.587917        11.903910       0.236214
#
#    trc_count_1000  metro_km_walk  big_market_km  price_doc
# 0               3       1.131260      10.814172    5850000
# 1               5       0.635053       6.910568    6000000
# 2               0       1.445960       5.752368    5700000
# 3               6       0.963802      27.892717   13100000
# 4               3       0.688859       9.155057   16331452
#
# [5 rows x 21 columns]

# %%
dataFrame.shape
# Out:
# (30471, 21)

# %% [markdown]
# # Descriptive Statistics

# %%
dataFrame.describe()
# Out:
#        oil_chemistry_km  big_church_km      water_km       park_km  \
# count      30471.000000   30471.000000  30471.000000  30471.000000
# mean          17.401611       2.330047      0.690947      3.099942
# std           10.399510       2.986937      0.434919      3.965363
# min            0.510710       0.004072      0.006707      0.003737
# 25%            8.720666       0.860469      0.339637      0.973297
# 50%           16.698447       1.490794      0.621221      1.803889
# 75%           23.424518       2.922264      0.963865      3.404787
# max           70.413434      45.669060      2.827709     47.351538
#
#        power_transmission_line_km  radiation_km   cemetery_km  \
# count                30471.000000  30471.000000  30471.000000
# mean                     3.492231      4.410781      2.314765
# std                      4.552470      5.595367      1.451071
# min                      0.030266      0.004663      0.000000
# 25%                      0.976235      1.231846      1.334801
# 50%                      1.895715      2.435160      1.968520
# 75%                      4.926551      4.687054      3.089480
# max                     43.324371     53.890157     15.778710
#
#        kindergarten_km  healthcare_centers_raion      full_all  ...  \
# count     30471.000000              30471.000000  3.047100e+04  ...
# mean          0.981684                  1.320895  1.463062e+05  ...
# std           2.121956                  1.492903  2.830251e+05  ...
# min           0.000470                  0.000000  2.546000e+03  ...
# 25%           0.199946                  0.000000  2.817900e+04  ...
# 50%           0.353762                  1.000000  8.521900e+04  ...
# 75%           0.971417                  2.000000  1.251110e+05  ...
# max          29.085774                  6.000000  1.716730e+06  ...
#
#           school_km  zd_vokzaly_avto_km  trc_count_1500  \
# count  30471.000000        30471.000000    30471.000000
# mean       1.323956           17.214848        3.726002
# std        3.058145           10.300605        4.484812
# min        0.000000            0.136715        0.000000
# 25%        0.269716            9.992420        0.000000
# 50%        0.474862           14.757627        3.000000
# 75%        0.886531           24.061214        5.000000
# max       47.394706           91.215063       27.000000
#
#        thermal_power_plant_km  incineration_km  green_zone_km  trc_count_1000  \
# count            30471.000000     30471.000000   30471.000000    30471.000000
# mean                 7.340116        10.884613       0.300511        1.978176
# std                  5.619330         6.789709       0.298402        3.246328
# min                  0.400563         0.198071       0.000000        0.000000
# 25%                  3.770411         6.221938       0.100951        0.000000
# 50%                  5.892381        10.324170       0.214336        1.000000
# 75%                  9.818719        13.393815       0.415498        3.000000
# max                 56.856147        58.632050       1.982448       20.000000
#
#        metro_km_walk  big_market_km     price_doc
# count   30446.000000   30471.000000  3.047100e+04
# mean        3.561467      13.283916  7.123035e+06
# std         5.775261       8.497170  4.780111e+06
# min         0.000000       0.661366  1.000000e+05
# 25%         0.957013       7.529625  4.740002e+06
# 50%         1.703934      11.910442  6.274411e+06
# 75%         3.776836      16.560167  8.300000e+06
# max        59.267984      59.501648  1.111111e+08
#
# [8 rows x 21 columns]

# %% [markdown]
# # Display the Complete Meta-Data of the dataset

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30471 entries, 0 to 30470
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   oil_chemistry_km            30471 non-null  float64
#  1   big_church_km               30471 non-null  float64
#  2   water_km                    30471 non-null  float64
#  3   park_km                     30471 non-null  float64
#  4   power_transmission_line_km  30471 non-null  float64
#  5   radiation_km                30471 non-null  float64
#  6   cemetery_km                 30471 non-null  float64
#  7   kindergarten_km             30471 non-null  float64
#  8   healthcare_centers_raion    30471 non-null  int64
#  9   full_all                    30471 non-null  int64
#  10  full_sq                     30471 non-null  int64
#  11  school_km                   30471 non-null  float64
#  12  zd_vokzaly_avto_km          30471 non-null  float64
#  13  trc_count_1500              30471 non-null  int64
#  14  thermal_power_plant_km      30471 non-null  float64
#  15  incineration_km             30471 non-null  float64
#  16  green_zone_km               30471 non-null  float64
#  17  trc_count_1000              30471 non-null  int64
#  18  metro_km_walk               30446 non-null  float64
#  19  big_market_km               30471 non-null  float64
#  20  price_doc                   30471 non-null  int64
# dtypes: float64(15), int64(6)
# memory usage: 4.9 MB

# %% [markdown]
# # Handling Duplicates

# %%
dataFrame.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 30466    False
# 30467    False
# 30468    False
# 30469    False
# 30470    False
# Length: 30471, dtype: bool

# %%
droped_dataFrame = dataFrame.drop_duplicates()
droped_dataFrame
# Out:
#        oil_chemistry_km  big_church_km  water_km   park_km  \
# 0             18.152338       0.625783  0.992631  2.158587
# 1              9.034642       0.967821  0.698081  0.550690
# 2              5.777394       3.178751  0.468265  0.374848
# 3             27.667863       1.031777  1.200336  0.078090
# 4              6.515857       0.378756  0.820294  0.258289
# ...                 ...            ...       ...       ...
# 30466         15.994941       1.235066  0.979218  1.972527
# 30467         10.988510       0.850385  1.063533  1.036452
# 30468         29.968660       1.192543  0.394422  4.566595
# 30469         19.591574       1.644053  0.738539  1.772506
# 30470          3.261652       0.480531  0.518509  0.848766
#
#        power_transmission_line_km  radiation_km  cemetery_km  kindergarten_km  \
# 0                        1.062513      1.210027     1.804127         0.145700
# 1                        1.246149      2.724295     4.655004         0.147754
# 2                        1.602183      0.772216     3.381083         0.049102
# 3                        1.767612      6.348716     2.017080         0.179441
# 4                        3.632640      1.638318     2.936581         0.247901
# ...                           ...           ...          ...              ...
# 30466                    2.046756      2.371148     1.933090         0.132645
# 30467                    3.295494      1.711271     1.336968         0.276256
# 30468                    5.506770      9.036942     2.250137         0.897889
# 30469                    1.971656      0.718679     3.216746         0.203020
# 30470                    1.832979      0.999365     1.791075         0.093619
#
#        healthcare_centers_raion  full_all  ...  school_km  zd_vokzaly_avto_km  \
# 0                             1     86206  ...   0.177975           14.231961
# 1                             1     76284  ...   0.273345            9.242586
# 2                             1    101982  ...   0.158072            9.540544
# 3                             1     21155  ...   0.236455           17.478380
# 4                             4     28179  ...   0.376838            1.595898
# ...                         ...       ...  ...        ...                 ...
# 30466                         1     61396  ...   0.349899           11.396447
# 30467                         3    116742  ...   0.362681            1.010437
# 30468                         0     17790  ...   1.234235           25.699461
# 30469                         2     83844  ...   0.130667           15.303338
# 30470                         2     72131  ...   0.378950           12.243439
#
#        trc_count_1500  thermal_power_plant_km  incineration_km  green_zone_km  \
# 0                   9                5.814135         3.633334       0.600973
# 1                   7                3.419574         8.648587       0.065321
# 2                   1                3.682455        11.996480       0.453172
# 3                   7               11.178333        14.317640       0.106125
# 4                   9                4.587917        11.903910       0.236214
# ...               ...                     ...              ...            ...
# 30466               6                6.668360         1.870053       0.139814
# 30467               7                5.408912         8.928301       0.271861
# 30468               0               10.102328        19.149190       0.427248
# 30469               1                6.417997         9.815678       0.227547
# 30470               5                5.239948         8.334879       0.559699
#
#        trc_count_1000  metro_km_walk  big_market_km  price_doc
# 0                   3       1.131260      10.814172    5850000
# 1                   5       0.635053       6.910568    6000000
# 2                   0       1.445960       5.752368    5700000
# 3                   6       0.963802      27.892717   13100000
# 4                   3       0.688859       9.155057   16331452
# ...               ...            ...            ...        ...
# 30466               3       0.679841       8.820934    7400000
# 30467               5       0.781217      12.102735   25000000
# 30468               0       1.722233      15.546028    6970959
# 30469               0       2.047312       2.515959   13500000
# 30470               4       0.454650      14.028112    5600000
#
# [28236 rows x 21 columns]

# %%
droped_dataFrame.shape
# Out:
# (28236, 21)

# %% [markdown]
# # Descriptive Statistics

# %%
droped_dataFrame.describe()
# Out:
#        oil_chemistry_km  big_church_km      water_km       park_km  \
# count      2.823600e+04   2.823600e+04  2.823600e+04  2.823600e+04
# mean       1.459439e-14  -3.306606e-14 -4.942460e-14  3.783996e-14
# std        1.000000e+00   1.000000e+00  1.000000e+00  1.000000e+00
# min       -1.449139e+00  -1.133873e+00 -1.398260e+00 -8.172817e-01
# 25%       -9.057573e-01  -7.256409e-01 -8.421102e-01 -6.071388e-01
# 50%       -2.547613e-02  -3.291325e-01 -1.586472e-01 -3.306568e-01
# 75%        7.400952e-01   4.421264e-01  6.636948e-01  1.122790e-01
# max        1.876328e+00   2.401861e+00  2.024250e+00  3.268589e+00
#
#        power_transmission_line_km  radiation_km   cemetery_km  \
# count                2.823600e+04  2.823600e+04  2.823600e+04
# mean                -7.684701e-15 -3.450707e-14  5.237790e-14
# std                  1.000000e+00  1.000000e+00  1.000000e+00
# min                 -9.446869e-01 -8.722020e-01 -1.464924e+00
# 25%                 -7.129862e-01 -6.867715e-01 -7.804484e-01
# 50%                 -3.974494e-01 -4.043467e-01 -2.016050e-01
# 75%                  4.761544e-01  1.985922e-01  6.509592e-01
# max                  2.743209e+00  2.713434e+00  2.032998e+00
#
#        kindergarten_km  healthcare_centers_raion      full_all  ...  \
# count     2.823600e+04              2.823600e+04  2.823600e+04  ...
# mean      2.426059e-14              3.718681e-15  1.075950e-15  ...
# std       1.000000e+00              1.000000e+00  1.000000e+00  ...
# min      -7.022275e-01             -9.378221e-01 -1.258895e+00  ...
# 25%      -5.954461e-01             -9.378221e-01 -8.332007e-01  ...
# 50%      -4.407526e-01             -2.592565e-01 -1.103048e-01  ...
# 75%       1.168615e-01              1.097875e+00  4.540324e-01  ...
# max       2.939062e+00              2.455006e+00  2.288848e+00  ...
#
#           school_km  zd_vokzaly_avto_km  trc_count_1500  \
# count  2.823600e+04        2.823600e+04    2.823600e+04
# mean   1.583676e-15        1.281742e-13    2.044924e-16
# std    1.000000e+00        1.000000e+00    1.000000e+00
# min   -7.160333e-01       -1.388385e+00   -1.089428e+00
# 25%   -5.868911e-01       -7.311116e-01   -7.821303e-01
# 50%   -4.093050e-01       -2.469348e-01   -1.675356e-01
# 75%   -7.569668e-02        7.611627e-01    7.543564e-01
# max    2.698896e+00        2.215857e+00    2.290843e+00
#
#        thermal_power_plant_km  incineration_km  green_zone_km  trc_count_1000  \
# count            2.823600e+04     2.823600e+04   2.823600e+04    2.823600e+04
# mean            -2.077003e-14    -9.011097e-14  -1.560548e-14   -2.418781e-15
# std              1.000000e+00     1.000000e+00   1.000000e+00    1.000000e+00
# min             -1.206779e+00    -1.528012e+00  -1.230757e+00   -8.966171e-01
# 25%             -7.405766e-01    -7.503086e-01  -7.937149e-01   -8.966171e-01
# 50%             -2.655254e-01    -5.407691e-02  -2.934090e-01   -3.748240e-01
# 75%              7.030403e-01     4.958952e-01   6.278600e-01    6.687623e-01
# max              2.674803e+00     2.258022e+00   2.298810e+00    2.234142e+00
#
#        metro_km_walk  big_market_km     price_doc
# count   2.823600e+04   2.823600e+04  2.823600e+04
# mean   -3.619743e-14  -3.665779e-14 -3.714894e-15
# std     1.000000e+00   1.000000e+00  1.000000e+00
# min    -7.552956e-01  -1.441128e+00 -1.516018e+00
# 25%    -5.836582e-01  -7.859635e-01 -6.293995e-01
# 50%    -3.785843e-01  -9.146214e-02 -1.760841e-01
# 75%     7.492494e-02   5.855744e-01  4.738497e-01
# max     3.180667e+00   2.152180e+00  2.402999e+00
#
# [8 rows x 21 columns]

# %% [markdown]
# #  Outliers

# %%
for col in  droped_dataFrame.columns:
    plt.boxplot(droped_dataFrame[col][~np.isnan(droped_dataFrame[col])])
    plt.title(col)
    plt.show()

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # Histogram Plot

# %%
for col in droped_dataFrame.columns:
    droped_dataFrame[col].hist()
    plt.title(col)
    plt.show()

# %% [markdown]
# # Box plot

# %%
for col in droped_dataFrame.columns:
    plt.boxplot(droped_dataFrame[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# # Scatter Plot

# %%
for col in droped_dataFrame.columns[:20]:
    dataFrame.plot(x=col,y="price_doc",kind = 'scatter')
    plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
droped_dataFrame.corr()
# Out:
#                             oil_chemistry_km  big_church_km  water_km  \
# oil_chemistry_km                    1.000000       0.546080 -0.128191
# big_church_km                       0.546080       1.000000 -0.012509
# water_km                           -0.128191      -0.012509  1.000000
# park_km                             0.719168       0.753406 -0.030916
# power_transmission_line_km          0.668850       0.691959 -0.087805
# radiation_km                        0.822449       0.731960 -0.114055
# cemetery_km                         0.090737       0.260482  0.018013
# kindergarten_km                     0.482997       0.720556 -0.038653
# healthcare_centers_raion           -0.393736      -0.282314 -0.033743
# full_all                           -0.193254      -0.096289  0.035236
# full_sq                             0.060850       0.044480 -0.017207
# school_km                           0.498735       0.913211 -0.037153
# zd_vokzaly_avto_km                  0.748418       0.717325 -0.103575
# trc_count_1500                     -0.292666      -0.335909 -0.036336
# thermal_power_plant_km              0.763500       0.764034 -0.096066
# incineration_km                     0.689829       0.549784 -0.100841
# green_zone_km                      -0.081226       0.044752  0.071461
# trc_count_1000                     -0.206800      -0.249567 -0.033280
# metro_km_walk                       0.705434       0.784752 -0.106179
# big_market_km                       0.643678       0.303684 -0.060530
# price_doc                          -0.114626      -0.183827 -0.018711
#
#                              park_km  power_transmission_line_km  \
# oil_chemistry_km            0.719168                    0.668850
# big_church_km               0.753406                    0.691959
# water_km                   -0.030916                   -0.087805
# park_km                     1.000000                    0.883262
# power_transmission_line_km  0.883262                    1.000000
# radiation_km                0.916108                    0.919603
# cemetery_km                 0.148285                    0.280485
# kindergarten_km             0.520138                    0.553125
# healthcare_centers_raion   -0.246985                   -0.203877
# full_all                   -0.071067                   -0.094696
# full_sq                     0.037040                    0.041527
# school_km                   0.642198                    0.619163
# zd_vokzaly_avto_km          0.784101                    0.733986
# trc_count_1500             -0.305111                   -0.181176
# thermal_power_plant_km      0.883744                    0.868189
# incineration_km             0.737771                    0.760259
# green_zone_km              -0.020014                    0.021308
# trc_count_1000             -0.228697                   -0.092350
# metro_km_walk               0.912069                    0.891382
# big_market_km               0.584192                    0.628627
# price_doc                  -0.179544                   -0.145854
#
#                             radiation_km  cemetery_km  kindergarten_km  \
# oil_chemistry_km                0.822449     0.090737         0.482997
# big_church_km                   0.731960     0.260482         0.720556
# water_km                       -0.114055     0.018013        -0.038653
# park_km                         0.916108     0.148285         0.520138
# power_transmission_line_km      0.919603     0.280485         0.553125
# radiation_km                    1.000000     0.147317         0.592052
# cemetery_km                     0.147317     1.000000         0.309576
# kindergarten_km                 0.592052     0.309576         1.000000
# healthcare_centers_raion       -0.304771    -0.011333        -0.251895
# full_all                       -0.132284    -0.027964        -0.129223
# full_sq                         0.039880     0.014308         0.047735
# school_km                       0.662722     0.202962         0.830327
# zd_vokzaly_avto_km              0.846800     0.113135         0.551409
# trc_count_1500                 -0.302762     0.090765        -0.205058
# thermal_power_plant_km          0.927802     0.167894         0.611101
# incineration_km                 0.789919     0.114536         0.501382
# green_zone_km                  -0.030139     0.032830         0.065348
# trc_count_1000                 -0.215931     0.136755        -0.130658
# metro_km_walk                   0.903843     0.224658         0.639675
# big_market_km                   0.666667     0.107519         0.241866
# price_doc                      -0.187273     0.002867        -0.130530
#
#                             healthcare_centers_raion  full_all  ...  \
# oil_chemistry_km                           -0.393736 -0.193254  ...
# big_church_km                              -0.282314 -0.096289  ...
# water_km                                   -0.033743  0.035236  ...
# park_km                                    -0.246985 -0.071067  ...
# power_transmission_line_km                 -0.203877 -0.094696  ...
# radiation_km                               -0.304771 -0.132284  ...
# cemetery_km                                -0.011333 -0.027964  ...
# kindergarten_km                            -0.251895 -0.129223  ...
# healthcare_centers_raion                    1.000000  0.145935  ...
# full_all                                    0.145935  1.000000  ...
# full_sq                                    -0.007208  0.013785  ...
# school_km                                  -0.258570 -0.122906  ...
# zd_vokzaly_avto_km                         -0.454278 -0.134309  ...
# trc_count_1500                              0.338785 -0.053193  ...
# thermal_power_plant_km                     -0.340380 -0.140248  ...
# incineration_km                            -0.096169 -0.159526  ...
# green_zone_km                              -0.042367 -0.004879  ...
# trc_count_1000                              0.266265 -0.048700  ...
# metro_km_walk                              -0.228089 -0.060877  ...
# big_market_km                              -0.052453 -0.041520  ...
# price_doc                                   0.174205  0.021296  ...
#
#                             school_km  zd_vokzaly_avto_km  trc_count_1500  \
# oil_chemistry_km             0.498735            0.748418       -0.292666
# big_church_km                0.913211            0.717325       -0.335909
# water_km                    -0.037153           -0.103575       -0.036336
# park_km                      0.642198            0.784101       -0.305111
# power_transmission_line_km   0.619163            0.733986       -0.181176
# radiation_km                 0.662722            0.846800       -0.302762
# cemetery_km                  0.202962            0.113135        0.090765
# kindergarten_km              0.830327            0.551409       -0.205058
# healthcare_centers_raion    -0.258570           -0.454278        0.338785
# full_all                    -0.122906           -0.134309       -0.053193
# full_sq                      0.051469            0.037223        0.006019
# school_km                    1.000000            0.604216       -0.244413
# zd_vokzaly_avto_km           0.604216            1.000000       -0.453364
# trc_count_1500              -0.244413           -0.453364        1.000000
# thermal_power_plant_km       0.681421            0.856410       -0.307880
# incineration_km              0.543259            0.577256       -0.153367
# green_zone_km               -0.013565            0.013702       -0.087463
# trc_count_1000              -0.181890           -0.329802        0.891557
# metro_km_walk                0.719500            0.747589       -0.279656
# big_market_km                0.237681            0.424956       -0.155862
# price_doc                   -0.140613           -0.272094        0.137509
#
#                             thermal_power_plant_km  incineration_km  \
# oil_chemistry_km                          0.763500         0.689829
# big_church_km                             0.764034         0.549784
# water_km                                 -0.096066        -0.100841
# park_km                                   0.883744         0.737771
# power_transmission_line_km                0.868189         0.760259
# radiation_km                              0.927802         0.789919
# cemetery_km                               0.167894         0.114536
# kindergarten_km                           0.611101         0.501382
# healthcare_centers_raion                 -0.340380        -0.096169
# full_all                                 -0.140248        -0.159526
# full_sq                                   0.043927         0.050480
# school_km                                 0.681421         0.543259
# zd_vokzaly_avto_km                        0.856410         0.577256
# trc_count_1500                           -0.307880        -0.153367
# thermal_power_plant_km                    1.000000         0.677367
# incineration_km                           0.677367         1.000000
# green_zone_km                             0.018469        -0.128822
# trc_count_1000                           -0.211794        -0.090219
# metro_km_walk                             0.862777         0.721866
# big_market_km                             0.566137         0.571183
# price_doc                                -0.201288        -0.061145
#
#                             green_zone_km  trc_count_1000  metro_km_walk  \
# oil_chemistry_km                -0.081226       -0.206800       0.705434
# big_church_km                    0.044752       -0.249567       0.784752
# water_km                         0.071461       -0.033280      -0.106179
# park_km                         -0.020014       -0.228697       0.912069
# power_transmission_line_km       0.021308       -0.092350       0.891382
# radiation_km                    -0.030139       -0.215931       0.903843
# cemetery_km                      0.032830        0.136755       0.224658
# kindergarten_km                  0.065348       -0.130658       0.639675
# healthcare_centers_raion        -0.042367        0.266265      -0.228089
# full_all                        -0.004879       -0.048700      -0.060877
# full_sq                         -0.005950        0.010006       0.032793
# school_km                       -0.013565       -0.181890       0.719500
# zd_vokzaly_avto_km               0.013702       -0.329802       0.747589
# trc_count_1500                  -0.087463        0.891557      -0.279656
# thermal_power_plant_km           0.018469       -0.211794       0.862777
# incineration_km                 -0.128822       -0.090219       0.721866
# green_zone_km                    1.000000       -0.059136      -0.043332
# trc_count_1000                  -0.059136        1.000000      -0.202223
# metro_km_walk                   -0.043332       -0.202223       1.000000
# big_market_km                   -0.015507       -0.115411       0.590887
# price_doc                       -0.058581        0.069416      -0.177022
#
#                             big_market_km  price_doc
# oil_chemistry_km                 0.643678  -0.114626
# big_church_km                    0.303684  -0.183827
# water_km                        -0.060530  -0.018711
# park_km                          0.584192  -0.179544
# power_transmission_line_km       0.628627  -0.145854
# radiation_km                     0.666667  -0.187273
# cemetery_km                      0.107519   0.002867
# kindergarten_km                  0.241866  -0.130530
# healthcare_centers_raion        -0.052453   0.174205
# full_all                        -0.041520   0.021296
# full_sq                          0.020270   0.338387
# school_km                        0.237681  -0.140613
# zd_vokzaly_avto_km               0.424956  -0.272094
# trc_count_1500                  -0.155862   0.137509
# thermal_power_plant_km           0.566137  -0.201288
# incineration_km                  0.571183  -0.061145
# green_zone_km                   -0.015507  -0.058581
# trc_count_1000                  -0.115411   0.069416
# metro_km_walk                    0.590887  -0.177022
# big_market_km                    1.000000  -0.048948
# price_doc                       -0.048948   1.000000
#
# [21 rows x 21 columns]

# %%
pd.DataFrame(droped_dataFrame.corr().iloc[:,-1])
# Out:
#                             price_doc
# oil_chemistry_km            -0.114626
# big_church_km               -0.183827
# water_km                    -0.018711
# park_km                     -0.179544
# power_transmission_line_km  -0.145854
# radiation_km                -0.187273
# cemetery_km                  0.002867
# kindergarten_km             -0.130530
# healthcare_centers_raion     0.174205
# full_all                     0.021296
# full_sq                      0.338387
# school_km                   -0.140613
# zd_vokzaly_avto_km          -0.272094
# trc_count_1500               0.137509
# thermal_power_plant_km      -0.201288
# incineration_km             -0.061145
# green_zone_km               -0.058581
# trc_count_1000               0.069416
# metro_km_walk               -0.177022
# big_market_km               -0.048948
# price_doc                    1.000000

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(20,10))
sns.heatmap(droped_dataFrame.corr(),annot=True)
plt.show()

# %% [markdown]
# # Handling Missing Values

# %%
droped_dataFrame.isnull().sum()
# Out:
# oil_chemistry_km               0
# big_church_km                  0
# water_km                       0
# park_km                        0
# power_transmission_line_km     0
# radiation_km                   0
# cemetery_km                    0
# kindergarten_km                0
# healthcare_centers_raion       0
# full_all                       0
# full_sq                        0
# school_km                      0
# zd_vokzaly_avto_km             0
# trc_count_1500                 0
# thermal_power_plant_km         0
# incineration_km                0
# green_zone_km                  0
# trc_count_1000                 0
# metro_km_walk                 25
# big_market_km                  0
# price_doc                      0
# dtype: int64

# %%
null_columns = ["metro_km_walk"]
for col in null_columns:
    droped_dataFrame[col] = droped_dataFrame[col].fillna(droped_dataFrame[col].mean())
# Out:
# C:\Users\kd67152\AppData\Local\Temp\ipykernel_28956\2346741970.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   droped_dataFrame[col] = droped_dataFrame[col].fillna(droped_dataFrame[col].mean())

# %%
droped_dataFrame.isnull().sum()
# Out:
# oil_chemistry_km              0
# big_church_km                 0
# water_km                      0
# park_km                       0
# power_transmission_line_km    0
# radiation_km                  0
# cemetery_km                   0
# kindergarten_km               0
# healthcare_centers_raion      0
# full_all                      0
# full_sq                       0
# school_km                     0
# zd_vokzaly_avto_km            0
# trc_count_1500                0
# thermal_power_plant_km        0
# incineration_km               0
# green_zone_km                 0
# trc_count_1000                0
# metro_km_walk                 0
# big_market_km                 0
# price_doc                     0
# dtype: int64

# %% [markdown]
# # Handling Outliers

# %%
for col in droped_dataFrame.columns:
    q1 = droped_dataFrame[col].quantile(0.05)
    q3 = droped_dataFrame[col].quantile(0.95)
    droped_dataFrame[col].clip(upper=q3,lower=q1,inplace=True)
# Out:
# C:\Users\kd67152\AppData\Local\Temp\ipykernel_28956\531386290.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   droped_dataFrame[col].clip(upper=q3,lower=q1,inplace=True)

# %%
for col in droped_dataFrame.columns:
    plt.boxplot(droped_dataFrame[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# # Standardization

# %%
for col in droped_dataFrame.columns:
    mean = droped_dataFrame[col].mean()
    std = droped_dataFrame[col].std()
    droped_dataFrame[col] = (droped_dataFrame[col] - mean)/std
# Out:
# C:\Users\kd67152\AppData\Local\Temp\ipykernel_28956\1270106349.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   droped_dataFrame[col] = (droped_dataFrame[col] - mean)/std

# %% [raw]
# from sklearn.preprocessing import StandardScaler,MinMaxScaler
# def scalling(data_frame):
#         sc=MinMaxScaler()
#         sc.fit(data_frame)
#         data=pd.DataFrame(sc.transform(data_frame),columns=data_frame.columns)
#         return data
# data= scalling(droped_dataFrame)
# data.head()

# %%
droped_dataFrame
# Out:
#        oil_chemistry_km  big_church_km  water_km   park_km  \
# 0              0.149623      -0.865417  0.807364 -0.201957
# 1             -0.873827      -0.633310  0.063326 -0.739695
# 2             -1.239450       0.867027 -0.517194 -0.798502
# 3              1.217730      -0.589910  1.332031 -0.817282
# 4             -1.156558      -1.033050  0.372038 -0.817282
# ...                 ...            ...       ...       ...
# 30466         -0.092542      -0.451958  0.773483 -0.264182
# 30467         -0.654508      -0.713002  0.986464 -0.577238
# 30468          1.475992      -0.480814 -0.703722  0.603367
# 30469          0.311176      -0.174419  0.165524 -0.331076
# 30470         -1.449139      -0.963985 -0.390275 -0.640007
#
#        power_transmission_line_km  radiation_km  cemetery_km  kindergarten_km  \
# 0                       -0.678538     -0.683221    -0.332670        -0.641716
# 1                       -0.610579     -0.287883     2.032998        -0.639643
# 2                       -0.478822     -0.797523     1.080592        -0.702228
# 3                       -0.417601      0.658364    -0.141822        -0.607688
# 4                        0.272589     -0.571405     0.682231        -0.538646
# ...                           ...           ...          ...              ...
# 30466                   -0.314299     -0.380081    -0.217094        -0.654881
# 30467                    0.147822     -0.552359    -0.751336        -0.510050
# 30468                    0.966148      1.360194     0.067042         0.116862
# 30469                   -0.342091     -0.811500     0.933314        -0.583908
# 30470                   -0.393411     -0.738220    -0.344367        -0.694238
#
#        healthcare_centers_raion  full_all  ...  school_km  zd_vokzaly_avto_km  \
# 0                     -0.259256 -0.093713  ...  -0.673451           -0.242379
# 1                     -0.259256 -0.240305  ...  -0.587168           -0.784778
# 2                     -0.259256  0.139368  ...  -0.691458           -0.752386
# 3                     -0.259256 -1.054802  ...  -0.620543            0.110541
# 4                      1.776440 -0.951026  ...  -0.493536           -1.388385
# ...                         ...       ...  ...        ...                 ...
# 30466                 -0.259256 -0.460266  ...  -0.517908           -0.550630
# 30467                  1.097875  0.357437  ...  -0.506345           -1.388385
# 30468                 -0.937822 -1.104517  ...   0.282167            1.004261
# 30469                  0.419309 -0.128610  ...  -0.716033           -0.125909
# 30470                  0.419309 -0.301663  ...  -0.491626           -0.458553
#
#        trc_count_1500  thermal_power_plant_km  incineration_km  green_zone_km  \
# 0            1.676248               -0.233102        -1.262803       1.535664
# 1            1.061654               -0.799963        -0.360792      -1.004338
# 2           -0.782130               -0.737731         0.241338       0.834809
# 3            1.061654                1.036758         0.658806      -0.810853
# 4            1.676248               -0.523383         0.224689      -0.193983
# ...               ...                     ...              ...            ...
# 30466        0.754356               -0.030882        -1.528012      -0.651104
# 30467        1.061654               -0.329029        -0.310485      -0.024949
# 30468       -1.089428                0.782037         1.527778       0.711877
# 30469       -0.782130               -0.090150        -0.150887      -0.235081
# 30470        0.447059               -0.369028        -0.417214       1.339946
#
#        trc_count_1000  metro_km_walk  big_market_km  price_doc
# 0            0.668762      -0.525829      -0.291589  -0.337251
# 1            1.712349      -0.674473      -0.867755  -0.291325
# 2           -0.896617      -0.431557      -1.038704  -0.383177
# 3            2.234142      -0.575992       2.152180   1.882505
# 4            0.668762      -0.658354      -0.536472   2.402999
# ...               ...            ...            ...        ...
# 30466        0.668762      -0.661056      -0.585788   0.137317
# 30467        1.712349      -0.630687      -0.101399   2.402999
# 30468       -0.896617      -0.348797       0.406826   0.005956
# 30469       -0.896617      -0.251416      -1.441128   2.004974
# 30470        1.190555      -0.728514       0.182784  -0.413795
#
# [28236 rows x 21 columns]

# %% [raw]
# from sklearn import preprocessing
# standard = preprocessing.scale(droped_dataFrame)
# print(standard)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X = droped_dataFrame.drop(["price_doc"],axis=1)
y = droped_dataFrame["price_doc"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0)

# %%
model = LinearRegression().fit(X_train,y_train)

# %%
model.score(X_test,y_test)
# Out:
# 0.5130585239562329

# %%
model.score(X_train,y_train)
# Out:
# 0.5035844405513313
