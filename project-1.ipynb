# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the Dataset

# %%
train_data = pd.read_csv(r"C:\Users\kd67152\Desktop\Datasets\train.csv")

# %% [markdown]
# # Display the FIRST 5 Observations

# %%
train_data.head()
# Out:
#    id   timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0   1  2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 1   2  2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 2   3  2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 3   4  2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 4   5  2011-09-05       77     77.0    4.0        NaN       NaN         NaN
#
#    num_room  kitch_sq  ...  cafe_count_5000_price_2500  \
# 0       NaN       NaN  ...                           9
# 1       NaN       NaN  ...                          15
# 2       NaN       NaN  ...                          10
# 3       NaN       NaN  ...                          11
# 4       NaN       NaN  ...                         319
#
#   cafe_count_5000_price_4000 cafe_count_5000_price_high  \
# 0                          4                          0
# 1                          3                          0
# ...

# %% [markdown]
# # finding the correlation with respect to dependent variable

# %%
data = pd.DataFrame(train_data.corr())
data
# Out:
#                           id   full_sq   life_sq     floor  max_floor  \
# id                  1.000000  0.021447  0.014478 -0.022523   0.007037
# full_sq             0.021447  1.000000  0.161112  0.089649   0.119225
# life_sq             0.014478  0.161112  1.000000  0.045090   0.042442
# floor              -0.022523  0.089649  0.045090  1.000000   0.454488
# max_floor           0.007037  0.119225  0.042442  0.454488   1.000000
# ...                      ...       ...       ...       ...        ...
# mosque_count_5000  -0.048797  0.021568  0.009945 -0.012256  -0.058255
# leisure_count_5000  0.020671  0.030218  0.022737 -0.044236  -0.048664
# sport_count_5000   -0.011680  0.001580 -0.014499 -0.102101  -0.099855
# market_count_5000  -0.025627 -0.041254 -0.050337 -0.123843  -0.113341
# price_doc           0.121203  0.341840  0.165606  0.117447   0.094386
#
#                     material  build_year  num_room  kitch_sq     state  ...  \
# ...

# %% [markdown]
# # Tacking last row of the data

# %%
data2 = pd.DataFrame(train_data.corr().iloc[:,-1])
data2
# Out:
#                     price_doc
# id                   0.121203
# full_sq              0.341840
# life_sq              0.165606
# floor                0.117447
# max_floor            0.094386
# ...                       ...
# mosque_count_5000    0.175107
# leisure_count_5000   0.200448
# sport_count_5000     0.294864
# market_count_5000    0.194021
# price_doc            1.000000
#
# [276 rows x 1 columns]

# %% [markdown]
# # Selected features

# %%
selected_features = data2[data2["price_doc"]>=0.2].index
selected_features
# Out:
# Index(['full_sq', 'num_room', 'sport_objects_raion', 'sport_count_1500',
#        'office_sqm_2000', 'sport_count_2000', 'office_sqm_3000',
#        'trc_count_3000', 'trc_sqm_3000', 'sport_count_3000',
#        'office_count_5000', 'office_sqm_5000', 'trc_count_5000',
#        'trc_sqm_5000', 'cafe_count_5000', 'cafe_count_5000_na_price',
#        'cafe_count_5000_price_500', 'cafe_count_5000_price_1000',
#        'cafe_count_5000_price_1500', 'cafe_count_5000_price_2500',
#        'cafe_count_5000_price_4000', 'cafe_count_5000_price_high',
#        'church_count_5000', 'leisure_count_5000', 'sport_count_5000',
#        'price_doc'],
#       dtype='object')

# %% [markdown]
# # Create a DataFrame with selected Featurs

# %%
dataFrame = pd.DataFrame(train_data[selected_features])

# %%
dataFrame.drop(["num_room"],axis=1)
dataFrame.head()
# Out:
#    full_sq  num_room  sport_objects_raion  sport_count_1500  office_sqm_2000  \
# 0       43       NaN                    7                 7           188854
# 1       34       NaN                    6                 9           165510
# 2       43       NaN                    5                 6           100200
# 3       89       NaN                   17                 9            11000
# 4       77       NaN                   25                14          1625130
#
#    sport_count_2000  office_sqm_3000  trc_count_3000  trc_sqm_3000  \
# 0                10           251554              23       1419204
# 1                11           821986              14        491565
# 2                 8           110856               7         52550
# 3                13           167000              12        205756
# 4                21          3420907              60       2296870
#
#    sport_count_3000  ...  cafe_count_5000_price_500  \
# ...

# %%
dataFrame.tail()
# Out:
#        full_sq  num_room  sport_objects_raion  sport_count_1500  \
# 30466       44       2.0                   10                11
# 30467       86       4.0                   29                16
# 30468       45       1.0                    0                 0
# 30469       64       2.0                   11                15
# 30470       43       2.0                    7                 6
#
#        office_sqm_2000  sport_count_2000  office_sqm_3000  trc_count_3000  \
# 30466           224342                15           410183              22
# 30467          2186592                36          4208928              28
# 30468                0                 3                0               2
# 30469           107800                18           473168              25
# 30470                0                12           155237              13
#
#        trc_sqm_3000  sport_count_3000  ...  cafe_count_5000_price_500  \
# ...

# %%
dataFrame.shape
# Out:
# (30471, 26)

# %% [markdown]
# # Descriptive Statistics

# %%
dataFrame.describe()
# Out:
#             full_sq      num_room  sport_objects_raion  sport_count_1500  \
# count  30471.000000  20899.000000         30471.000000      30471.000000
# mean      54.214269      1.909804             6.635030          5.870795
# std       38.031487      0.851805             6.571982          5.756788
# min        0.000000      0.000000             0.000000          0.000000
# 25%       38.000000      1.000000             1.000000          1.000000
# 50%       49.000000      2.000000             5.000000          5.000000
# 75%       63.000000      2.000000            10.000000          9.000000
# max     5326.000000     19.000000            29.000000         37.000000
#
#        office_sqm_2000  sport_count_2000  office_sqm_3000  trc_count_3000  \
# count     3.047100e+04      30471.000000     3.047100e+04    30471.000000
# mean      2.464972e+05          9.846182     5.432616e+05       11.827442
# std       5.036364e+05          9.218370     1.056128e+06       10.914428
# ...

# %% [markdown]
# # Display the Complete Meta-Data of the dataset

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30471 entries, 0 to 30470
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   full_sq                     30471 non-null  int64
#  1   num_room                    20899 non-null  float64
#  2   sport_objects_raion         30471 non-null  int64
#  3   sport_count_1500            30471 non-null  int64
#  4   office_sqm_2000             30471 non-null  int64
#  5   sport_count_2000            30471 non-null  int64
#  6   office_sqm_3000             30471 non-null  int64
#  7   trc_count_3000              30471 non-null  int64
#  8   trc_sqm_3000                30471 non-null  int64
#  9   sport_count_3000            30471 non-null  int64
#  10  office_count_5000           30471 non-null  int64
#  11  office_sqm_5000             30471 non-null  int64
#  12  trc_count_5000              30471 non-null  int64
# ...

# %% [markdown]
# # Handling Duplicates

# %%
dataFrame.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 30466    False
# 30467    False
# 30468    False
# 30469    False
# 30470    False
# Length: 30471, dtype: bool

# %%
droped_dataFrame = dataFrame.drop_duplicates()
droped_dataFrame
# Out:
#        full_sq  num_room  sport_objects_raion  sport_count_1500  \
# 0           43       NaN                    7                 7
# 1           34       NaN                    6                 9
# 2           43       NaN                    5                 6
# 3           89       NaN                   17                 9
# 4           77       NaN                   25                14
# ...        ...       ...                  ...               ...
# 30466       44       2.0                   10                11
# 30467       86       4.0                   29                16
# 30468       45       1.0                    0                 0
# 30469       64       2.0                   11                15
# 30470       43       2.0                    7                 6
#
#        office_sqm_2000  sport_count_2000  office_sqm_3000  trc_count_3000  \
# 0               188854                10           251554              23
# ...

# %% [markdown]
# # Handling Missing Values

# %%
droped_dataFrame.isnull().sum()
# Out:
# full_sq                          0
# num_room                      8638
# sport_objects_raion              0
# sport_count_1500                 0
# office_sqm_2000                  0
# sport_count_2000                 0
# office_sqm_3000                  0
# trc_count_3000                   0
# trc_sqm_3000                     0
# sport_count_3000                 0
# office_count_5000                0
# office_sqm_5000                  0
# trc_count_5000                   0
# trc_sqm_5000                     0
# cafe_count_5000                  0
# cafe_count_5000_na_price         0
# cafe_count_5000_price_500        0
# cafe_count_5000_price_1000       0
# cafe_count_5000_price_1500       0
# cafe_count_5000_price_2500       0
# cafe_count_5000_price_4000       0
# cafe_count_5000_price_high       0
# church_count_5000                0
# leisure_count_5000               0
# sport_count_5000                 0
# price_doc                        0
# dtype: int64

# %%
droped_dataFrame['num_room'] = droped_dataFrame['num_room'].fillna(droped_dataFrame['num_room'].median())
# Out:
# C:\Users\kd67152\AppData\Local\Temp\ipykernel_20396\1525237633.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   droped_dataFrame['num_room'] = droped_dataFrame['num_room'].fillna(droped_dataFrame['num_room'].median())

# %%
droped_dataFrame.isnull().sum()
# Out:
# full_sq                       0
# num_room                      0
# sport_objects_raion           0
# sport_count_1500              0
# office_sqm_2000               0
# sport_count_2000              0
# office_sqm_3000               0
# trc_count_3000                0
# trc_sqm_3000                  0
# sport_count_3000              0
# office_count_5000             0
# office_sqm_5000               0
# trc_count_5000                0
# trc_sqm_5000                  0
# cafe_count_5000               0
# cafe_count_5000_na_price      0
# cafe_count_5000_price_500     0
# cafe_count_5000_price_1000    0
# cafe_count_5000_price_1500    0
# cafe_count_5000_price_2500    0
# cafe_count_5000_price_4000    0
# cafe_count_5000_price_high    0
# church_count_5000             0
# leisure_count_5000            0
# sport_count_5000              0
# price_doc                     0
# dtype: int64

# %% [markdown]
# # Handling Outliers

# %%
for col in  droped_dataFrame.columns:
    plt.boxplot(droped_dataFrame[col])
    plt.title(col)
    plt.show()

# %%
for col in droped_dataFrame.columns:
    p0 = droped_dataFrame[col].min()
    p100 = droped_dataFrame[col].max()
    q1 = droped_dataFrame[col].quantile(0.25)
    q2 = droped_dataFrame[col].quantile(0.5)
    q3 = droped_dataFrame[col].quantile(0.75)
    iqr=q3-q1
    lc = q1 - 1.5*iqr
    uc = q3 + 1.5*iqr
    droped_dataFrame[col]=np.where(droped_dataFrame[col] >= uc,uc,droped_dataFrame[col])
    droped_dataFrame[col]=np.where(droped_dataFrame[col] <= lc,lc,droped_dataFrame[col])
# Out:
# C:\Users\kd67152\AppData\Local\Temp\ipykernel_20396\3548704184.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   droped_dataFrame[col]=np.where(droped_dataFrame[col] >= uc,uc,droped_dataFrame[col])
# C:\Users\kd67152\AppData\Local\Temp\ipykernel_20396\3548704184.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   droped_dataFrame[col]=np.where(droped_dataFrame[col] <= lc,lc,droped_dataFrame[col])

# %%
for col in  droped_dataFrame.columns:
    plt.boxplot(droped_dataFrame[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # Histogram Plot

# %%
for col in droped_dataFrame.columns:
    droped_dataFrame[col].hist()
    plt.title(col)
    plt.show()

# %% [markdown]
# # Box plot

# %%
for col in droped_dataFrame.columns:
    plt.boxplot(droped_dataFrame[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
droped_dataFrame.plot(x='full_sq',y='num_room',kind = 'scatter')
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
droped_dataFrame.select_dtypes(['float64' , 'int64']).corr()
# Out:
#                              full_sq  num_room  sport_objects_raion  \
# full_sq                     1.000000       NaN             0.022580
# num_room                         NaN       NaN                  NaN
# sport_objects_raion         0.022580       NaN             1.000000
# sport_count_1500           -0.019837       NaN             0.756174
# office_sqm_2000            -0.004837       NaN             0.461977
# sport_count_2000           -0.016308       NaN             0.756100
# office_sqm_3000             0.000067       NaN             0.487801
# trc_count_3000             -0.016543       NaN             0.646265
# trc_sqm_3000               -0.018127       NaN             0.544579
# sport_count_3000           -0.017462       NaN             0.712166
# office_count_5000          -0.005280       NaN             0.536253
# office_sqm_5000            -0.008809       NaN             0.512098
# trc_count_5000             -0.028651       NaN             0.652734
# ...

# %% [markdown]
# # Heatmap

# %% [markdown]
# # Scatter Plot

# %%
for col in droped_dataFrame.columns[:21]:
    dataFrame.plot(x=col,y="price_doc",kind = 'scatter')
    plt.show()

# %%
corr = droped_dataFrame.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\kd67152\Anaconda3\lib\site-packages\pandas\io\formats\style.py:3554: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# C:\Users\kd67152\Anaconda3\lib\site-packages\pandas\io\formats\style.py:3555: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_4d3ff_row0_col0, #T_4d3ff_row2_col2, #T_4d3ff_row3_col3, #T_4d3ff_row4_col4, #T_4d3ff_row5_col5, #T_4d3ff_row6_col6, #T_4d3ff_row7_col7, #T_4d3ff_row8_col8, #T_4d3ff_row9_col9, #T_4d3ff_row10_col10, #T_4d3ff_row11_col11, #T_4d3ff_row12_col12, #T_4d3ff_row13_col13, #T_4d3ff_row14_col14, #T_4d3ff_row15_col15, #T_4d3ff_row16_col16, #T_4d3ff_row17_col17, #T_4d3ff_row18_col18, #T_4d3ff_row19_col19, #T_4d3ff_row20_col20, #T_4d3ff_row21_col21, #T_4d3ff_row22_col22, #T_4d3ff_row23_col23, #T_4d3ff_row24_col24, #T_4d3ff_row25_col25 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# ...
