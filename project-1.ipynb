# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the Dataset

# %%
train_data = pd.read_csv(r"C:\Users\kd67152\Desktop\Datasets\train.csv")

# %% [markdown]
# # Display the FIRST 5 Observations

# %%
train_data.head()
# Out:
#    id   timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0   1  2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 1   2  2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 2   3  2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 3   4  2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 4   5  2011-09-05       77     77.0    4.0        NaN       NaN         NaN
#
#    num_room  kitch_sq  ...  cafe_count_5000_price_2500  \
# 0       NaN       NaN  ...                           9
# 1       NaN       NaN  ...                          15
# 2       NaN       NaN  ...                          10
# 3       NaN       NaN  ...                          11
# 4       NaN       NaN  ...                         319
#
#   cafe_count_5000_price_4000 cafe_count_5000_price_high  \
# 0                          4                          0
# 1                          3                          0
# 2                          3                          0
# 3                          2                          1
# 4                        108                         17
#
#    big_church_count_5000  church_count_5000  mosque_count_5000  \
# 0                     13                 22                  1
# 1                     15                 29                  1
# 2                     11                 27                  0
# 3                      4                  4                  0
# 4                    135                236                  2
#
#    leisure_count_5000  sport_count_5000  market_count_5000  price_doc
# 0                   0                52                  4    5850000
# 1                  10                66                 14    6000000
# 2                   4                67                 10    5700000
# 3                   0                26                  3   13100000
# 4                  91               195                 14   16331452
#
# [5 rows x 292 columns]

# %% [markdown]
# # finding the correlation with respect to dependent variable

# %%
data = pd.DataFrame(train_data.corr())
data
# Out:
#                           id   full_sq   life_sq     floor  max_floor  \
# id                  1.000000  0.021447  0.014478 -0.022523   0.007037
# full_sq             0.021447  1.000000  0.161112  0.089649   0.119225
# life_sq             0.014478  0.161112  1.000000  0.045090   0.042442
# floor              -0.022523  0.089649  0.045090  1.000000   0.454488
# max_floor           0.007037  0.119225  0.042442  0.454488   1.000000
# ...                      ...       ...       ...       ...        ...
# mosque_count_5000  -0.048797  0.021568  0.009945 -0.012256  -0.058255
# leisure_count_5000  0.020671  0.030218  0.022737 -0.044236  -0.048664
# sport_count_5000   -0.011680  0.001580 -0.014499 -0.102101  -0.099855
# market_count_5000  -0.025627 -0.041254 -0.050337 -0.123843  -0.113341
# price_doc           0.121203  0.341840  0.165606  0.117447   0.094386
#
#                     material  build_year  num_room  kitch_sq     state  ...  \
# id                  0.008507   -0.012726  0.014387 -0.010414 -0.119621  ...
# full_sq             0.032866   -0.006041  0.695444  0.020026 -0.091348  ...
# life_sq             0.011393   -0.002401  0.191024  0.000633 -0.066633  ...
# floor              -0.009043    0.001192 -0.005657 -0.008457 -0.113906  ...
# max_floor           0.045915   -0.000261 -0.014220  0.020345 -0.072161  ...
# ...                      ...         ...       ...       ...       ...  ...
# mosque_count_5000   0.050355    0.019631  0.062785  0.013183  0.091894  ...
# leisure_count_5000  0.044502   -0.000830  0.058663 -0.006259 -0.003876  ...
# sport_count_5000    0.098482    0.005978  0.089908  0.016866  0.194379  ...
# market_count_5000   0.076378    0.007362  0.061674  0.026404  0.273385  ...
# price_doc           0.064047    0.002161  0.476337  0.028718  0.121303  ...
#
#                     cafe_count_5000_price_2500  cafe_count_5000_price_4000  \
# id                                    0.018635                    0.022958
# full_sq                               0.039083                    0.040059
# life_sq                               0.028735                    0.031551
# floor                                -0.034791                   -0.029636
# max_floor                            -0.040235                   -0.033662
# ...                                        ...                         ...
# mosque_count_5000                     0.529434                    0.492859
# leisure_count_5000                    0.986206                    0.975462
# sport_count_5000                      0.824139                    0.778770
# market_count_5000                     0.432265                    0.380154
# price_doc                             0.225566                    0.210354
#
#                     cafe_count_5000_price_high  big_church_count_5000  \
# id                                    0.023704               0.012813
# full_sq                               0.043560               0.026895
# life_sq                               0.034888               0.017845
# floor                                -0.022303              -0.044398
# max_floor                            -0.029525              -0.048235
# ...                                        ...                    ...
# mosque_count_5000                     0.481481               0.502028
# leisure_count_5000                    0.948391               0.969029
# sport_count_5000                      0.753384               0.825883
# market_count_5000                     0.353270               0.482547
# price_doc                             0.214327               0.198827
#
#                     church_count_5000  mosque_count_5000  leisure_count_5000  \
# id                           0.015181          -0.048797            0.020671
# full_sq                      0.028579           0.021568            0.030218
# life_sq                      0.018114           0.009945            0.022737
# floor                       -0.045614          -0.012256           -0.044236
# max_floor                   -0.048240          -0.058255           -0.048664
# ...                               ...                ...                 ...
# mosque_count_5000            0.550342           1.000000            0.499376
# leisure_count_5000           0.975259           0.499376            1.000000
# sport_count_5000             0.847771           0.518500            0.809169
# market_count_5000            0.514344           0.242078            0.463053
# price_doc                    0.213275           0.175107            0.200448
#
#                     sport_count_5000  market_count_5000  price_doc
# id                         -0.011680          -0.025627   0.121203
# full_sq                     0.001580          -0.041254   0.341840
# life_sq                    -0.014499          -0.050337   0.165606
# floor                      -0.102101          -0.123843   0.117447
# max_floor                  -0.099855          -0.113341   0.094386
# ...                              ...                ...        ...
# mosque_count_5000           0.518500           0.242078   0.175107
# leisure_count_5000          0.809169           0.463053   0.200448
# sport_count_5000            1.000000           0.733897   0.294864
# market_count_5000           0.733897           1.000000   0.194021
# price_doc                   0.294864           0.194021   1.000000
#
# [276 rows x 276 columns]

# %% [markdown]
# # Tacking last row of the data

# %%
data2 = pd.DataFrame(train_data.corr().iloc[:,-1])
data2
# Out:
#                     price_doc
# id                   0.121203
# full_sq              0.341840
# life_sq              0.165606
# floor                0.117447
# max_floor            0.094386
# ...                       ...
# mosque_count_5000    0.175107
# leisure_count_5000   0.200448
# sport_count_5000     0.294864
# market_count_5000    0.194021
# price_doc            1.000000
#
# [276 rows x 1 columns]

# %% [markdown]
# # Selected features

# %%
selected_features = data2[data2["price_doc"]>=0.2].index
len(selected_features)
# Out:
# 26

# %% [markdown]
# # Create a DataFrame with selected Featurs

# %%
dataFrame = pd.DataFrame(train_data[selected_features])
dataFrame
# Out:
#        full_sq  num_room  sport_objects_raion  sport_count_1500  \
# 0           43       NaN                    7                 7
# 1           34       NaN                    6                 9
# 2           43       NaN                    5                 6
# 3           89       NaN                   17                 9
# 4           77       NaN                   25                14
# ...        ...       ...                  ...               ...
# 30466       44       2.0                   10                11
# 30467       86       4.0                   29                16
# 30468       45       1.0                    0                 0
# 30469       64       2.0                   11                15
# 30470       43       2.0                    7                 6
#
#        office_sqm_2000  sport_count_2000  office_sqm_3000  trc_count_3000  \
# 0               188854                10           251554              23
# 1               165510                11           821986              14
# 2               100200                 8           110856               7
# 3                11000                13           167000              12
# 4              1625130                21          3420907              60
# ...                ...               ...              ...             ...
# 30466           224342                15           410183              22
# 30467          2186592                36          4208928              28
# 30468                0                 3                0               2
# 30469           107800                18           473168              25
# 30470                0                12           155237              13
#
#        trc_sqm_3000  sport_count_3000  ...  cafe_count_5000_price_500  \
# 0           1419204                21  ...                         39
# 1            491565                19  ...                         49
# 2             52550                20  ...                         29
# 3            205756                18  ...                          7
# 4           2296870                77  ...                        566
# ...             ...               ...  ...                        ...
# 30466        745130                29  ...                         63
# 30467        845372                80  ...                        550
# 30468         22000                 6  ...                          4
# 30469        481350                33  ...                         60
# 30470        545023                26  ...                         26
#
#        cafe_count_5000_price_1000  cafe_count_5000_price_1500  \
# 0                              48                          40
# 1                              65                          36
# 2                              45                          25
# 3                              21                          15
# 4                             578                         552
# ...                           ...                         ...
# 30466                          59                          47
# 30467                         535                         511
# 30468                           8                           5
# 30469                          77                          58
# 30470                          35                          22
#
#        cafe_count_5000_price_2500  cafe_count_5000_price_4000  \
# 0                               9                           4
# 1                              15                           3
# 2                              10                           3
# 3                              11                           2
# 4                             319                         108
# ...                           ...                         ...
# 30466                          15                           5
# 30467                         313                         128
# 30468                           1                           1
# 30469                          22                           1
# 30470                           5                           2
#
#        cafe_count_5000_price_high  church_count_5000  leisure_count_5000  \
# 0                               0                 22                   0
# 1                               0                 29                  10
# 2                               0                 27                   4
# 3                               1                  4                   0
# 4                              17                236                  91
# ...                           ...                ...                 ...
# 30466                           0                 26                   2
# 30467                          24                182                  82
# 30468                           0                 12                   1
# 30469                           1                 31                   4
# 30470                           0                 16                   9
#
#        sport_count_5000  price_doc
# 0                    52    5850000
# 1                    66    6000000
# 2                    67    5700000
# 3                    26   13100000
# 4                   195   16331452
# ...                 ...        ...
# 30466                84    7400000
# 30467               171   25000000
# 30468                11    6970959
# 30469                65   13500000
# 30470                54    5600000
#
# [30471 rows x 26 columns]

# %%
dataFrame1 = dataFrame.drop(["num_room"],axis=1)
dataFrame1.head()
# Out:
#    full_sq  sport_objects_raion  sport_count_1500  office_sqm_2000  \
# 0       43                    7                 7           188854
# 1       34                    6                 9           165510
# 2       43                    5                 6           100200
# 3       89                   17                 9            11000
# 4       77                   25                14          1625130
#
#    sport_count_2000  office_sqm_3000  trc_count_3000  trc_sqm_3000  \
# 0                10           251554              23       1419204
# 1                11           821986              14        491565
# 2                 8           110856               7         52550
# 3                13           167000              12        205756
# 4                21          3420907              60       2296870
#
#    sport_count_3000  office_count_5000  ...  cafe_count_5000_price_500  \
# 0                21                 29  ...                         39
# 1                19                 66  ...                         49
# 2                20                 43  ...                         29
# 3                18                  8  ...                          7
# 4                77                689  ...                        566
#
#    cafe_count_5000_price_1000  cafe_count_5000_price_1500  \
# 0                          48                          40
# 1                          65                          36
# 2                          45                          25
# 3                          21                          15
# 4                         578                         552
#
#    cafe_count_5000_price_2500  cafe_count_5000_price_4000  \
# 0                           9                           4
# 1                          15                           3
# 2                          10                           3
# 3                          11                           2
# 4                         319                         108
#
#    cafe_count_5000_price_high  church_count_5000  leisure_count_5000  \
# 0                           0                 22                   0
# 1                           0                 29                  10
# 2                           0                 27                   4
# 3                           1                  4                   0
# 4                          17                236                  91
#
#    sport_count_5000  price_doc
# 0                52    5850000
# 1                66    6000000
# 2                67    5700000
# 3                26   13100000
# 4               195   16331452
#
# [5 rows x 25 columns]

# %%
dataFrame1.tail()
# Out:
#        full_sq  sport_objects_raion  sport_count_1500  office_sqm_2000  \
# 30466       44                   10                11           224342
# 30467       86                   29                16          2186592
# 30468       45                    0                 0                0
# 30469       64                   11                15           107800
# 30470       43                    7                 6                0
#
#        sport_count_2000  office_sqm_3000  trc_count_3000  trc_sqm_3000  \
# 30466                15           410183              22        745130
# 30467                36          4208928              28        845372
# 30468                 3                0               2         22000
# 30469                18           473168              25        481350
# 30470                12           155237              13        545023
#
#        sport_count_3000  office_count_5000  ...  cafe_count_5000_price_500  \
# 30466                29                 44  ...                         63
# 30467                80                617  ...                        550
# 30468                 6                  1  ...                          4
# 30469                33                 39  ...                         60
# 30470                26                 15  ...                         26
#
#        cafe_count_5000_price_1000  cafe_count_5000_price_1500  \
# 30466                          59                          47
# 30467                         535                         511
# 30468                           8                           5
# 30469                          77                          58
# 30470                          35                          22
#
#        cafe_count_5000_price_2500  cafe_count_5000_price_4000  \
# 30466                          15                           5
# 30467                         313                         128
# 30468                           1                           1
# 30469                          22                           1
# 30470                           5                           2
#
#        cafe_count_5000_price_high  church_count_5000  leisure_count_5000  \
# 30466                           0                 26                   2
# 30467                          24                182                  82
# 30468                           0                 12                   1
# 30469                           1                 31                   4
# 30470                           0                 16                   9
#
#        sport_count_5000  price_doc
# 30466                84    7400000
# 30467               171   25000000
# 30468                11    6970959
# 30469                65   13500000
# 30470                54    5600000
#
# [5 rows x 25 columns]

# %%
dataFrame1.shape
# Out:
# (30471, 25)

# %% [markdown]
# # Descriptive Statistics

# %%
dataFrame1.describe()
# Out:
#             full_sq  sport_objects_raion  sport_count_1500  office_sqm_2000  \
# count  30471.000000         30471.000000      30471.000000     3.047100e+04
# mean      54.214269             6.635030          5.870795     2.464972e+05
# std       38.031487             6.571982          5.756788     5.036364e+05
# min        0.000000             0.000000          0.000000     0.000000e+00
# 25%       38.000000             1.000000          1.000000     0.000000e+00
# 50%       49.000000             5.000000          5.000000     5.841100e+04
# 75%       63.000000            10.000000          9.000000     2.071930e+05
# max     5326.000000            29.000000         37.000000     3.602982e+06
#
#        sport_count_2000  office_sqm_3000  trc_count_3000  trc_sqm_3000  \
# count      30471.000000     3.047100e+04    30471.000000  3.047100e+04
# mean           9.846182     5.432616e+05       11.827442  4.381316e+05
# std            9.218370     1.056128e+06       10.914428  4.697316e+05
# min            0.000000     0.000000e+00        0.000000  0.000000e+00
# 25%            2.000000     0.000000e+00        2.000000  4.110000e+04
# 50%            9.000000     1.303030e+05       11.000000  2.943500e+05
# 75%           14.000000     4.947065e+05       17.000000  6.594530e+05
# max           54.000000     6.106112e+06       66.000000  2.654102e+06
#
#        sport_count_3000  office_count_5000  ...  cafe_count_5000_price_500  \
# count      30471.000000       30471.000000  ...               30471.000000
# mean          20.239310          71.356240  ...                  66.195530
# std           18.843867         155.341362  ...                 125.934584
# min            0.000000           0.000000  ...                   0.000000
# 25%            5.000000           2.000000  ...                   4.000000
# 50%           18.000000          15.000000  ...                  28.000000
# 75%           29.000000          53.000000  ...                  59.000000
# max          100.000000         789.000000  ...                 650.000000
#
#        cafe_count_5000_price_1000  cafe_count_5000_price_1500  \
# count                30471.000000                30471.000000
# mean                    73.442421                   63.469660
# std                    126.167671                  124.076662
# min                      0.000000                    0.000000
# 25%                      8.000000                    6.000000
# 50%                     36.000000                   24.000000
# 75%                     69.000000                   51.000000
# max                    648.000000                  641.000000
#
#        cafe_count_5000_price_2500  cafe_count_5000_price_4000  \
# count                30471.000000                30471.000000
# mean                    32.058318                   10.783860
# std                     73.465611                   28.385679
# min                      0.000000                    0.000000
# 25%                      2.000000                    1.000000
# 50%                      8.000000                    2.000000
# 75%                     21.000000                    5.000000
# max                    377.000000                  147.000000
#
#        cafe_count_5000_price_high  church_count_5000  leisure_count_5000  \
# count                30471.000000       30471.000000        30471.000000
# mean                     1.771783          30.251518            8.648814
# std                      5.418807          47.347938           20.580741
# min                      0.000000           0.000000            0.000000
# 25%                      0.000000           9.000000            0.000000
# 50%                      0.000000          16.000000            2.000000
# 75%                      1.000000          28.000000            7.000000
# max                     30.000000         250.000000          106.000000
#
#        sport_count_5000     price_doc
# count      30471.000000  3.047100e+04
# mean          52.796593  7.123035e+06
# std           46.292660  4.780111e+06
# min            0.000000  1.000000e+05
# 25%           11.000000  4.740002e+06
# 50%           48.000000  6.274411e+06
# 75%           76.000000  8.300000e+06
# max          218.000000  1.111111e+08
#
# [8 rows x 25 columns]

# %% [markdown]
# # Display the Complete Meta-Data of the dataset

# %%
dataFrame1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30471 entries, 0 to 30470
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   full_sq                     30471 non-null  int64
#  1   sport_objects_raion         30471 non-null  int64
#  2   sport_count_1500            30471 non-null  int64
#  3   office_sqm_2000             30471 non-null  int64
#  4   sport_count_2000            30471 non-null  int64
#  5   office_sqm_3000             30471 non-null  int64
#  6   trc_count_3000              30471 non-null  int64
#  7   trc_sqm_3000                30471 non-null  int64
#  8   sport_count_3000            30471 non-null  int64
#  9   office_count_5000           30471 non-null  int64
#  10  office_sqm_5000             30471 non-null  int64
#  11  trc_count_5000              30471 non-null  int64
#  12  trc_sqm_5000                30471 non-null  int64
#  13  cafe_count_5000             30471 non-null  int64
#  14  cafe_count_5000_na_price    30471 non-null  int64
#  15  cafe_count_5000_price_500   30471 non-null  int64
#  16  cafe_count_5000_price_1000  30471 non-null  int64
#  17  cafe_count_5000_price_1500  30471 non-null  int64
#  18  cafe_count_5000_price_2500  30471 non-null  int64
#  19  cafe_count_5000_price_4000  30471 non-null  int64
#  20  cafe_count_5000_price_high  30471 non-null  int64
#  21  church_count_5000           30471 non-null  int64
#  22  leisure_count_5000          30471 non-null  int64
#  23  sport_count_5000            30471 non-null  int64
#  24  price_doc                   30471 non-null  int64
# dtypes: int64(25)
# memory usage: 5.8 MB

# %% [markdown]
# # Handling Duplicates

# %%
dataFrame1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 30466    False
# 30467    False
# 30468    False
# 30469    False
# 30470    False
# Length: 30471, dtype: bool

# %%
droped_dataFrame = dataFrame1.drop_duplicates()
droped_dataFrame
# Out:
#        full_sq  sport_objects_raion  sport_count_1500  office_sqm_2000  \
# 0           43                    7                 7           188854
# 1           34                    6                 9           165510
# 2           43                    5                 6           100200
# 3           89                   17                 9            11000
# 4           77                   25                14          1625130
# ...        ...                  ...               ...              ...
# 30466       44                   10                11           224342
# 30467       86                   29                16          2186592
# 30468       45                    0                 0                0
# 30469       64                   11                15           107800
# 30470       43                    7                 6                0
#
#        sport_count_2000  office_sqm_3000  trc_count_3000  trc_sqm_3000  \
# 0                    10           251554              23       1419204
# 1                    11           821986              14        491565
# 2                     8           110856               7         52550
# 3                    13           167000              12        205756
# 4                    21          3420907              60       2296870
# ...                 ...              ...             ...           ...
# 30466                15           410183              22        745130
# 30467                36          4208928              28        845372
# 30468                 3                0               2         22000
# 30469                18           473168              25        481350
# 30470                12           155237              13        545023
#
#        sport_count_3000  office_count_5000  ...  cafe_count_5000_price_500  \
# 0                    21                 29  ...                         39
# 1                    19                 66  ...                         49
# 2                    20                 43  ...                         29
# 3                    18                  8  ...                          7
# 4                    77                689  ...                        566
# ...                 ...                ...  ...                        ...
# 30466                29                 44  ...                         63
# 30467                80                617  ...                        550
# 30468                 6                  1  ...                          4
# 30469                33                 39  ...                         60
# 30470                26                 15  ...                         26
#
#        cafe_count_5000_price_1000  cafe_count_5000_price_1500  \
# 0                              48                          40
# 1                              65                          36
# 2                              45                          25
# 3                              21                          15
# 4                             578                         552
# ...                           ...                         ...
# 30466                          59                          47
# 30467                         535                         511
# 30468                           8                           5
# 30469                          77                          58
# 30470                          35                          22
#
#        cafe_count_5000_price_2500  cafe_count_5000_price_4000  \
# 0                               9                           4
# 1                              15                           3
# 2                              10                           3
# 3                              11                           2
# 4                             319                         108
# ...                           ...                         ...
# 30466                          15                           5
# 30467                         313                         128
# 30468                           1                           1
# 30469                          22                           1
# 30470                           5                           2
#
#        cafe_count_5000_price_high  church_count_5000  leisure_count_5000  \
# 0                               0                 22                   0
# 1                               0                 29                  10
# 2                               0                 27                   4
# 3                               1                  4                   0
# 4                              17                236                  91
# ...                           ...                ...                 ...
# 30466                           0                 26                   2
# 30467                          24                182                  82
# 30468                           0                 12                   1
# 30469                           1                 31                   4
# 30470                           0                 16                   9
#
#        sport_count_5000  price_doc
# 0                    52    5850000
# 1                    66    6000000
# 2                    67    5700000
# 3                    26   13100000
# 4                   195   16331452
# ...                 ...        ...
# 30466                84    7400000
# 30467               171   25000000
# 30468                11    6970959
# 30469                65   13500000
# 30470                54    5600000
#
# [28114 rows x 25 columns]

# %% [markdown]
# # Outliers

# %%
for col in  droped_dataFrame.columns:
    plt.boxplot(droped_dataFrame[col])
    plt.title(col)
    plt.show()

# %% [raw]
# for col in  droped_dataFrame.columns:
#     plt.boxplot(droped_dataFrame[col])
#     plt.title(col)
#     plt.show()

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # Histogram Plot

# %%
for col in droped_dataFrame.columns:
    droped_dataFrame[col].hist()
    plt.title(col)
    plt.show()

# %% [markdown]
# # Box plot

# %%
for col in droped_dataFrame.columns:
    plt.boxplot(droped_dataFrame[col][~np.isnan(droped_dataFrame[col])])
    plt.title(col)
    plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
for col in droped_dataFrame.columns[:20]:
    dataFrame.plot(x=col,y="price_doc",kind = 'scatter')
    plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
droped_dataFrame.corr()
# Out:
#                              full_sq  sport_objects_raion  sport_count_1500  \
# full_sq                     1.000000             0.028201          0.002858
# sport_objects_raion         0.028201             1.000000          0.774340
# sport_count_1500            0.002858             0.774340          1.000000
# office_sqm_2000             0.025891             0.604308          0.673898
# sport_count_2000            0.008051             0.781932          0.936246
# office_sqm_3000             0.029376             0.642653          0.717807
# trc_count_3000              0.003553             0.690957          0.782868
# trc_sqm_3000               -0.003349             0.551174          0.633901
# sport_count_3000            0.009973             0.749388          0.867154
# office_count_5000           0.031469             0.656365          0.728784
# office_sqm_5000             0.026036             0.645542          0.718211
# trc_count_5000             -0.000719             0.675516          0.779957
# trc_sqm_5000               -0.007604             0.599736          0.720677
# cafe_count_5000             0.034534             0.671897          0.744725
# cafe_count_5000_na_price    0.033304             0.683931          0.753361
# cafe_count_5000_price_500   0.030470             0.666010          0.747296
# cafe_count_5000_price_1000  0.031637             0.676101          0.759064
# cafe_count_5000_price_1500  0.036855             0.668212          0.740822
# cafe_count_5000_price_2500  0.039178             0.665562          0.721839
# cafe_count_5000_price_4000  0.040159             0.653763          0.693753
# cafe_count_5000_price_high  0.043732             0.624541          0.658373
# church_count_5000           0.028427             0.660709          0.733410
# leisure_count_5000          0.030103             0.656277          0.709968
# sport_count_5000            0.000544             0.716796          0.820262
# price_doc                   0.338244             0.238555          0.244937
#
#                             office_sqm_2000  sport_count_2000  \
# full_sq                            0.025891          0.008051
# sport_objects_raion                0.604308          0.781932
# sport_count_1500                   0.673898          0.936246
# office_sqm_2000                    1.000000          0.720755
# sport_count_2000                   0.720755          1.000000
# office_sqm_3000                    0.949260          0.768907
# trc_count_3000                     0.709780          0.834737
# trc_sqm_3000                       0.619575          0.674270
# sport_count_3000                   0.762474          0.940967
# office_count_5000                  0.888890          0.778268
# office_sqm_5000                    0.889694          0.772314
# trc_count_5000                     0.725418          0.832456
# trc_sqm_5000                       0.644365          0.762567
# cafe_count_5000                    0.892847          0.794397
# cafe_count_5000_na_price           0.888015          0.800975
# cafe_count_5000_price_500          0.888022          0.798141
# cafe_count_5000_price_1000         0.888346          0.811663
# cafe_count_5000_price_1500         0.889490          0.789960
# cafe_count_5000_price_2500         0.892183          0.768407
# cafe_count_5000_price_4000         0.888139          0.735050
# cafe_count_5000_price_high         0.880070          0.703125
# church_count_5000                  0.855649          0.781160
# leisure_count_5000                 0.878559          0.755470
# sport_count_5000                   0.778642          0.882599
# price_doc                          0.210409          0.265851
#
#                             office_sqm_3000  trc_count_3000  trc_sqm_3000  \
# full_sq                            0.029376        0.003553     -0.003349
# sport_objects_raion                0.642653        0.690957      0.551174
# sport_count_1500                   0.717807        0.782868      0.633901
# office_sqm_2000                    0.949260        0.709780      0.619575
# sport_count_2000                   0.768907        0.834737      0.674270
# office_sqm_3000                    1.000000        0.757528      0.647064
# trc_count_3000                     0.757528        1.000000      0.800428
# trc_sqm_3000                       0.647064        0.800428      1.000000
# sport_count_3000                   0.820808        0.860770      0.699292
# office_count_5000                  0.954378        0.762224      0.623891
# office_sqm_5000                    0.953442        0.740529      0.637233
# trc_count_5000                     0.782841        0.899273      0.742227
# trc_sqm_5000                       0.687971        0.779131      0.815990
# cafe_count_5000                    0.955279        0.776587      0.633088
# cafe_count_5000_na_price           0.950873        0.779505      0.656912
# cafe_count_5000_price_500          0.951736        0.781577      0.633680
# cafe_count_5000_price_1000         0.952901        0.796349      0.643906
# cafe_count_5000_price_1500         0.952989        0.780483      0.633427
# cafe_count_5000_price_2500         0.950796        0.741065      0.608657
# cafe_count_5000_price_4000         0.938677        0.700442      0.581286
# cafe_count_5000_price_high         0.924815        0.655239      0.555830
# church_count_5000                  0.925735        0.789795      0.625602
# leisure_count_5000                 0.935371        0.733219      0.591611
# sport_count_5000                   0.840779        0.822885      0.685628
# price_doc                          0.221640        0.228566      0.210758
#
#                             sport_count_3000  office_count_5000  ...  \
# full_sq                             0.009973           0.031469  ...
# sport_objects_raion                 0.749388           0.656365  ...
# sport_count_1500                    0.867154           0.728784  ...
# office_sqm_2000                     0.762474           0.888890  ...
# sport_count_2000                    0.940967           0.778268  ...
# office_sqm_3000                     0.820808           0.954378  ...
# trc_count_3000                      0.860770           0.762224  ...
# trc_sqm_3000                        0.699292           0.623891  ...
# sport_count_3000                    1.000000           0.834590  ...
# office_count_5000                   0.834590           1.000000  ...
# office_sqm_5000                     0.842022           0.961377  ...
# trc_count_5000                      0.882216           0.791743  ...
# trc_sqm_5000                        0.797976           0.682838  ...
# cafe_count_5000                     0.845002           0.992704  ...
# cafe_count_5000_na_price            0.846055           0.985808  ...
# cafe_count_5000_price_500           0.851425           0.992398  ...
# cafe_count_5000_price_1000          0.866586           0.990743  ...
# cafe_count_5000_price_1500          0.839513           0.991161  ...
# cafe_count_5000_price_2500          0.815107           0.986464  ...
# cafe_count_5000_price_4000          0.773118           0.965828  ...
# cafe_count_5000_price_high          0.747029           0.938032  ...
# church_count_5000                   0.833845           0.982437  ...
# leisure_count_5000                  0.803144           0.979908  ...
# sport_count_5000                    0.947055           0.854767  ...
# price_doc                           0.279140           0.216620  ...
#
#                             cafe_count_5000_price_500  \
# full_sq                                      0.030470
# sport_objects_raion                          0.666010
# sport_count_1500                             0.747296
# office_sqm_2000                              0.888022
# sport_count_2000                             0.798141
# office_sqm_3000                              0.951736
# trc_count_3000                               0.781577
# trc_sqm_3000                                 0.633680
# sport_count_3000                             0.851425
# office_count_5000                            0.992398
# office_sqm_5000                              0.951183
# trc_count_5000                               0.808952
# trc_sqm_5000                                 0.698544
# cafe_count_5000                              0.997880
# cafe_count_5000_na_price                     0.989632
# cafe_count_5000_price_500                    1.000000
# cafe_count_5000_price_1000                   0.996616
# cafe_count_5000_price_1500                   0.993882
# cafe_count_5000_price_2500                   0.990534
# cafe_count_5000_price_4000                   0.970711
# cafe_count_5000_price_high                   0.949475
# church_count_5000                            0.978345
# leisure_count_5000                           0.979913
# sport_count_5000                             0.864437
# price_doc                                    0.223558
#
#                             cafe_count_5000_price_1000  \
# full_sq                                       0.031637
# sport_objects_raion                           0.676101
# sport_count_1500                              0.759064
# office_sqm_2000                               0.888346
# sport_count_2000                              0.811663
# office_sqm_3000                               0.952901
# trc_count_3000                                0.796349
# trc_sqm_3000                                  0.643906
# sport_count_3000                              0.866586
# office_count_5000                             0.990743
# office_sqm_5000                               0.956564
# trc_count_5000                                0.830165
# trc_sqm_5000                                  0.712674
# cafe_count_5000                               0.997204
# cafe_count_5000_na_price                      0.986622
# cafe_count_5000_price_500                     0.996616
# cafe_count_5000_price_1000                    1.000000
# cafe_count_5000_price_1500                    0.995707
# cafe_count_5000_price_2500                    0.987615
# cafe_count_5000_price_4000                    0.963492
# cafe_count_5000_price_high                    0.939446
# church_count_5000                             0.979400
# leisure_count_5000                            0.978098
# sport_count_5000                              0.881405
# price_doc                                     0.236622
#
#                             cafe_count_5000_price_1500  \
# full_sq                                       0.036855
# sport_objects_raion                           0.668212
# sport_count_1500                              0.740822
# office_sqm_2000                               0.889490
# sport_count_2000                              0.789960
# office_sqm_3000                               0.952989
# trc_count_3000                                0.780483
# trc_sqm_3000                                  0.633427
# sport_count_3000                              0.839513
# office_count_5000                             0.991161
# office_sqm_5000                               0.948725
# trc_count_5000                                0.803647
# trc_sqm_5000                                  0.688910
# cafe_count_5000                               0.998207
# cafe_count_5000_na_price                      0.989750
# cafe_count_5000_price_500                     0.993882
# cafe_count_5000_price_1000                    0.995707
# cafe_count_5000_price_1500                    1.000000
# cafe_count_5000_price_2500                    0.992985
# cafe_count_5000_price_4000                    0.975045
# cafe_count_5000_price_high                    0.946914
# church_count_5000                             0.981927
# leisure_count_5000                            0.983717
# sport_count_5000                              0.849397
# price_doc                                     0.230301
#
#                             cafe_count_5000_price_2500  \
# full_sq                                       0.039178
# sport_objects_raion                           0.665562
# sport_count_1500                              0.721839
# office_sqm_2000                               0.892183
# sport_count_2000                              0.768407
# office_sqm_3000                               0.950796
# trc_count_3000                                0.741065
# trc_sqm_3000                                  0.608657
# sport_count_3000                              0.815107
# office_count_5000                             0.986464
# office_sqm_5000                               0.942004
# trc_count_5000                                0.759599
# trc_sqm_5000                                  0.656255
# cafe_count_5000                               0.995671
# cafe_count_5000_na_price                      0.987583
# cafe_count_5000_price_500                     0.990534
# cafe_count_5000_price_1000                    0.987615
# cafe_count_5000_price_1500                    0.992985
# cafe_count_5000_price_2500                    1.000000
# cafe_count_5000_price_4000                    0.990101
# cafe_count_5000_price_high                    0.971567
# church_count_5000                             0.968670
# leisure_count_5000                            0.985618
# sport_count_5000                              0.825181
# price_doc                                     0.224123
#
#                             cafe_count_5000_price_4000  \
# full_sq                                       0.040159
# sport_objects_raion                           0.653763
# sport_count_1500                              0.693753
# office_sqm_2000                               0.888139
# sport_count_2000                              0.735050
# office_sqm_3000                               0.938677
# trc_count_3000                                0.700442
# trc_sqm_3000                                  0.581286
# sport_count_3000                              0.773118
# office_count_5000                             0.965828
# office_sqm_5000                               0.917938
# trc_count_5000                                0.710673
# trc_sqm_5000                                  0.620082
# cafe_count_5000                               0.979098
# cafe_count_5000_na_price                      0.976538
# cafe_count_5000_price_500                     0.970711
# cafe_count_5000_price_1000                    0.963492
# cafe_count_5000_price_1500                    0.975045
# cafe_count_5000_price_2500                    0.990101
# cafe_count_5000_price_4000                    1.000000
# cafe_count_5000_price_high                    0.980512
# church_count_5000                             0.942706
# leisure_count_5000                            0.974520
# sport_count_5000                              0.779135
# price_doc                                     0.209740
#
#                             cafe_count_5000_price_high  church_count_5000  \
# full_sq                                       0.043732           0.028427
# sport_objects_raion                           0.624541           0.660709
# sport_count_1500                              0.658373           0.733410
# office_sqm_2000                               0.880070           0.855649
# sport_count_2000                              0.703125           0.781160
# office_sqm_3000                               0.924815           0.925735
# trc_count_3000                                0.655239           0.789795
# trc_sqm_3000                                  0.555830           0.625602
# sport_count_3000                              0.747029           0.833845
# office_count_5000                             0.938032           0.982437
# office_sqm_5000                               0.902155           0.925417
# trc_count_5000                                0.663465           0.811149
# trc_sqm_5000                                  0.581776           0.685671
# cafe_count_5000                               0.956016           0.978857
# cafe_count_5000_na_price                      0.950409           0.968223
# cafe_count_5000_price_500                     0.949475           0.978345
# cafe_count_5000_price_1000                    0.939446           0.979400
# cafe_count_5000_price_1500                    0.946914           0.981927
# cafe_count_5000_price_2500                    0.971567           0.968670
# cafe_count_5000_price_4000                    0.980512           0.942706
# cafe_count_5000_price_high                    1.000000           0.896159
# church_count_5000                             0.896159           1.000000
# leisure_count_5000                            0.946380           0.974402
# sport_count_5000                              0.753654           0.847314
# price_doc                                     0.214163           0.209828
#
#                             leisure_count_5000  sport_count_5000  price_doc
# full_sq                               0.030103          0.000544   0.338244
# sport_objects_raion                   0.656277          0.716796   0.238555
# sport_count_1500                      0.709968          0.820262   0.244937
# office_sqm_2000                       0.878559          0.778642   0.210409
# sport_count_2000                      0.755470          0.882599   0.265851
# office_sqm_3000                       0.935371          0.840779   0.221640
# trc_count_3000                        0.733219          0.822885   0.228566
# trc_sqm_3000                          0.591611          0.685628   0.210758
# sport_count_3000                      0.803144          0.947055   0.279140
# office_count_5000                     0.979908          0.854767   0.216620
# office_sqm_5000                       0.920945          0.889866   0.264087
# trc_count_5000                        0.749988          0.917738   0.276415
# trc_sqm_5000                          0.635377          0.820600   0.252959
# cafe_count_5000                       0.984163          0.856826   0.228805
# cafe_count_5000_na_price              0.969672          0.858173   0.227098
# cafe_count_5000_price_500             0.979913          0.864437   0.223558
# cafe_count_5000_price_1000            0.978098          0.881405   0.236622
# cafe_count_5000_price_1500            0.983717          0.849397   0.230301
# cafe_count_5000_price_2500            0.985618          0.825181   0.224123
# cafe_count_5000_price_4000            0.974520          0.779135   0.209740
# cafe_count_5000_price_high            0.946380          0.753654   0.214163
# church_count_5000                     0.974402          0.847314   0.209828
# leisure_count_5000                    1.000000          0.809427   0.198146
# sport_count_5000                      0.809427          1.000000   0.282808
# price_doc                             0.198146          0.282808   1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# # Heatmap

# %%
corr = droped_dataFrame.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_96298_row0_col0, #T_96298_row1_col1, #T_96298_row2_col2, #T_96298_row3_col3, #T_96298_row4_col4, #T_96298_row5_col5, #T_96298_row6_col6, #T_96298_row7_col7, #T_96298_row8_col8, #T_96298_row9_col9, #T_96298_row10_col10, #T_96298_row11_col11, #T_96298_row12_col12, #T_96298_row13_col13, #T_96298_row13_col15, #T_96298_row13_col16, #T_96298_row13_col17, #T_96298_row14_col14, #T_96298_row15_col13, #T_96298_row15_col15, #T_96298_row15_col16, #T_96298_row16_col13, #T_96298_row16_col15, #T_96298_row16_col16, #T_96298_row17_col13, #T_96298_row17_col17, #T_96298_row18_col18, #T_96298_row19_col19, #T_96298_row20_col20, #T_96298_row21_col21, #T_96298_row22_col22, #T_96298_row23_col23, #T_96298_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_96298_row0_col1, #T_96298_row0_col2, #T_96298_row0_col3, #T_96298_row0_col4, #T_96298_row0_col5, #T_96298_row0_col6, #T_96298_row0_col7, #T_96298_row0_col8, #T_96298_row0_col9, #T_96298_row0_col10, #T_96298_row0_col11, #T_96298_row0_col12, #T_96298_row0_col13, #T_96298_row0_col14, #T_96298_row0_col15, #T_96298_row0_col16, #T_96298_row0_col17, #T_96298_row0_col18, #T_96298_row0_col19, #T_96298_row0_col20, #T_96298_row0_col21, #T_96298_row0_col22, #T_96298_row0_col23, #T_96298_row12_col0, #T_96298_row22_col24 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_96298_row0_col24, #T_96298_row24_col22 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_96298_row1_col0, #T_96298_row5_col0, #T_96298_row6_col24, #T_96298_row9_col0, #T_96298_row13_col24, #T_96298_row14_col24, #T_96298_row15_col0, #T_96298_row16_col0, #T_96298_row21_col0, #T_96298_row22_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_96298_row1_col2, #T_96298_row4_col1, #T_96298_row4_col21, #T_96298_row6_col15, #T_96298_row9_col4, #T_96298_row11_col5, #T_96298_row13_col6 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_96298_row1_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_96298_row1_col4, #T_96298_row2_col11, #T_96298_row3_col23, #T_96298_row6_col12, #T_96298_row11_col2, #T_96298_row12_col6, #T_96298_row14_col6, #T_96298_row15_col6, #T_96298_row17_col6, #T_96298_row19_col23, #T_96298_row21_col4 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_96298_row1_col5, #T_96298_row5_col1, #T_96298_row7_col16 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_96298_row1_col6, #T_96298_row4_col20, #T_96298_row5_col12, #T_96298_row6_col19, #T_96298_row12_col15, #T_96298_row17_col12, #T_96298_row21_col12 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_96298_row1_col7 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_96298_row1_col8, #T_96298_row4_col22, #T_96298_row11_col18, #T_96298_row15_col2 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_96298_row1_col9, #T_96298_row1_col22, #T_96298_row3_col12, #T_96298_row5_col7, #T_96298_row7_col14, #T_96298_row9_col1, #T_96298_row11_col20, #T_96298_row16_col7, #T_96298_row22_col1 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_96298_row1_col10, #T_96298_row2_col7, #T_96298_row7_col2, #T_96298_row7_col5, #T_96298_row10_col1, #T_96298_row12_col3, #T_96298_row13_col7, #T_96298_row15_col7, #T_96298_row17_col7 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_96298_row1_col11, #T_96298_row1_col14, #T_96298_row3_col2, #T_96298_row4_col7, #T_96298_row12_col9, #T_96298_row14_col1 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_96298_row1_col12, #T_96298_row12_col19 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_96298_row1_col13, #T_96298_row13_col1, #T_96298_row20_col11 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_96298_row1_col15, #T_96298_row1_col17, #T_96298_row18_col1, #T_96298_row20_col6 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_96298_row1_col16, #T_96298_row2_col3, #T_96298_row11_col1, #T_96298_row16_col1 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_96298_row1_col18, #T_96298_row1_col21, #T_96298_row21_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_96298_row1_col19, #T_96298_row6_col20, #T_96298_row10_col7, #T_96298_row22_col12 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_96298_row1_col20 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_96298_row1_col23, #T_96298_row3_col4, #T_96298_row5_col2, #T_96298_row10_col2, #T_96298_row11_col3, #T_96298_row14_col12 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_96298_row1_col24, #T_96298_row16_col24, #T_96298_row19_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_96298_row2_col0, #T_96298_row6_col0, #T_96298_row23_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_96298_row2_col1, #T_96298_row4_col10, #T_96298_row5_col4, #T_96298_row6_col13, #T_96298_row18_col4 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_96298_row2_col4, #T_96298_row4_col2, #T_96298_row5_col19, #T_96298_row9_col20, #T_96298_row16_col20, #T_96298_row19_col5, #T_96298_row20_col9, #T_96298_row20_col16 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_96298_row2_col5, #T_96298_row2_col10, #T_96298_row2_col18, #T_96298_row3_col6, #T_96298_row19_col11, #T_96298_row22_col2, #T_96298_row23_col1 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_96298_row2_col6, #T_96298_row4_col17, #T_96298_row5_col11, #T_96298_row6_col2, #T_96298_row6_col21, #T_96298_row11_col9 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_96298_row2_col8, #T_96298_row8_col2, #T_96298_row15_col23, #T_96298_row16_col8 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_96298_row2_col9, #T_96298_row12_col2, #T_96298_row18_col2 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_96298_row2_col12, #T_96298_row2_col21, #T_96298_row3_col11, #T_96298_row4_col19, #T_96298_row6_col22 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_96298_row2_col13, #T_96298_row8_col20, #T_96298_row10_col12 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_96298_row2_col14, #T_96298_row7_col11, #T_96298_row11_col7, #T_96298_row11_col22, #T_96298_row13_col2, #T_96298_row20_col8, #T_96298_row23_col20 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_96298_row2_col15, #T_96298_row8_col1, #T_96298_row10_col6, #T_96298_row17_col2, #T_96298_row18_col6 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_96298_row2_col16, #T_96298_row6_col5, #T_96298_row14_col2, #T_96298_row20_col23, #T_96298_row22_col4, #T_96298_row22_col11 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_96298_row2_col17, #T_96298_row6_col10, #T_96298_row6_col18, #T_96298_row19_col4, #T_96298_row21_col2, #T_96298_row22_col6 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_96298_row2_col19, #T_96298_row6_col1, #T_96298_row12_col13 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_96298_row2_col20, #T_96298_row12_col18, #T_96298_row19_col1 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_96298_row2_col22, #T_96298_row6_col3, #T_96298_row8_col7, #T_96298_row15_col12, #T_96298_row19_col6, #T_96298_row20_col4 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_96298_row2_col23, #T_96298_row5_col8, #T_96298_row7_col12, #T_96298_row11_col10, #T_96298_row12_col7, #T_96298_row23_col2, #T_96298_row23_col18 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_96298_row2_col24 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_96298_row3_col0, #T_96298_row10_col0, #T_96298_row15_col24, #T_96298_row18_col24 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_96298_row3_col1, #T_96298_row7_col18, #T_96298_row22_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_96298_row3_col5, #T_96298_row5_col3, #T_96298_row5_col14, #T_96298_row5_col18, #T_96298_row8_col23, #T_96298_row10_col14, #T_96298_row10_col17, #T_96298_row14_col10, #T_96298_row14_col20, #T_96298_row15_col20, #T_96298_row17_col10, #T_96298_row20_col14, #T_96298_row20_col15, #T_96298_row23_col8 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_96298_row3_col7, #T_96298_row7_col13, #T_96298_row7_col17 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_96298_row3_col8, #T_96298_row4_col18, #T_96298_row9_col6,

# %% [markdown]
# # Handling Missing Values

# %%
droped_dataFrame.isnull().sum()
# Out:
# full_sq                       0
# sport_objects_raion           0
# sport_count_1500              0
# office_sqm_2000               0
# sport_count_2000              0
# office_sqm_3000               0
# trc_count_3000                0
# trc_sqm_3000                  0
# sport_count_3000              0
# office_count_5000             0
# office_sqm_5000               0
# trc_count_5000                0
# trc_sqm_5000                  0
# cafe_count_5000               0
# cafe_count_5000_na_price      0
# cafe_count_5000_price_500     0
# cafe_count_5000_price_1000    0
# cafe_count_5000_price_1500    0
# cafe_count_5000_price_2500    0
# cafe_count_5000_price_4000    0
# cafe_count_5000_price_high    0
# church_count_5000             0
# leisure_count_5000            0
# sport_count_5000              0
# price_doc                     0
# dtype: int64

# %% [raw]
# null_columns = ["build_count_brick","life_sq"]
# for col in null_columns:
#     droped_dataFrame[col] = droped_dataFrame[col].fillna(droped_dataFrame[col].mean())

# %%
droped_dataFrame.isnull().sum()
# Out:
# full_sq                       0
# sport_objects_raion           0
# sport_count_1500              0
# office_sqm_2000               0
# sport_count_2000              0
# office_sqm_3000               0
# trc_count_3000                0
# trc_sqm_3000                  0
# sport_count_3000              0
# office_count_5000             0
# office_sqm_5000               0
# trc_count_5000                0
# trc_sqm_5000                  0
# cafe_count_5000               0
# cafe_count_5000_na_price      0
# cafe_count_5000_price_500     0
# cafe_count_5000_price_1000    0
# cafe_count_5000_price_1500    0
# cafe_count_5000_price_2500    0
# cafe_count_5000_price_4000    0
# cafe_count_5000_price_high    0
# church_count_5000             0
# leisure_count_5000            0
# sport_count_5000              0
# price_doc                     0
# dtype: int64

# %% [markdown]
# # Handling Outliners

# %%
for col in droped_dataFrame.columns:
    q1 = droped_dataFrame[col].quantile(0.05)
    q3 = droped_dataFrame[col].quantile(0.95)
    droped_dataFrame[col].clip(upper=q3,lower=q1,inplace=True)
# Out:
# C:\Users\kd67152\AppData\Local\Temp\ipykernel_10028\531386290.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   droped_dataFrame[col].clip(upper=q3,lower=q1,inplace=True)

# %% [markdown]
# # Standardization

# %%
for col in droped_dataFrame.columns:
    mean = droped_dataFrame[col].mean()
    std = droped_dataFrame[col].std()
    droped_dataFrame[col] = (droped_dataFrame[col] - mean)/std
# Out:
# C:\Users\kd67152\AppData\Local\Temp\ipykernel_10028\1270106349.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   droped_dataFrame[col] = (droped_dataFrame[col] - mean)/std

# %% [raw]
# from sklearn import preprocessing
# standard = preprocessing.scale(droped_dataFrame)
# standard

# %%
droped_dataFrame.head()
# Out:
#     full_sq  sport_objects_raion  sport_count_1500  office_sqm_2000  \
# 0 -0.575742             0.076237          0.226246        -0.093533
# 1 -1.108677            -0.107393          0.632899        -0.155571
# 2 -0.575742            -0.291023          0.022919        -0.329138
# 3  2.148148             1.912541          0.632899        -0.566194
# 4  1.437568             2.096171          1.649534         3.324192
#
#    sport_count_2000  office_sqm_3000  trc_count_3000  trc_sqm_3000  \
# 0          0.012286        -0.306474        1.343243      2.303516
# 1          0.139644         0.370379        0.282561      0.114369
# 2         -0.242432        -0.473421       -0.542414     -0.932050
# 3          0.394362        -0.406803        0.046854     -0.566874
# 4          1.413231         3.249726        2.050365      2.303516
#
#    sport_count_3000  office_count_5000  ...  cafe_count_5000_price_500  \
# 0          0.041763          -0.300973  ...                  -0.233080
# 1         -0.083912           0.004452  ...                  -0.129071
# 2         -0.021075          -0.185407  ...                  -0.337090
# 3         -0.146749          -0.474322  ...                  -0.565911
# 4          2.303907           3.400039  ...                   3.490467
#
#    cafe_count_5000_price_1000  cafe_count_5000_price_1500  \
# 0                   -0.215749                   -0.195424
# 1                   -0.039071                   -0.238412
# 2                   -0.246927                   -0.356631
# 3                   -0.496354                   -0.464103
# 4                    3.390550                    3.480104
#
#    cafe_count_5000_price_2500  cafe_count_5000_price_4000  \
# 0                   -0.357292                   -0.253348
# 1                   -0.247852                   -0.301933
# 2                   -0.339052                   -0.301933
# 3                   -0.320812                   -0.350518
# 4                    3.582531                    3.682024
#
#    cafe_count_5000_price_high  church_count_5000  leisure_count_5000  \
# 0                   -0.366810          -0.180108           -0.505053
# 1                   -0.366810           0.013034            0.156128
# 2                   -0.366810          -0.042149           -0.240581
# 3                   -0.122692          -0.676761           -0.505053
# 4                    3.783183           3.544786            3.594272
#
#    sport_count_5000  price_doc
# 0         -0.044793  -0.340603
# 1          0.291026  -0.294693
# 2          0.315013  -0.386512
# 3         -0.668458   1.878355
# 4          2.377903   2.398724
#
# [5 rows x 25 columns]

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X = droped_dataFrame.drop(["price_doc"],axis=1)
y = droped_dataFrame["price_doc"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0)

# %%
model = LinearRegression().fit(X_train,y_train)

# %%
model.score(X_train,y_train)
# Out:
# 0.496244234192008

# %%
model.score(X_test,y_test)
# Out:
# 0.5077294207262302

# %%
# from mlxtend.feature_selection import SequentialFeatureSelector
from mlxtend.feature_selection import SequentialFeatureSelector

feature_selector = SequentialFeatureSelector(LinearRegression(),
           k_features="best",
           forward=True,
           verbose=2,
           scoring='roc_auc',
           cv=4,
           n_jobs=-1)
feature_selector.fit(X_train,y_train)

# %% [markdown]
# # Coefficient

# %%
from sklearn.linear_model import Lasso

# %%
ls=Lasso(alpha=0.01,max_iter=2000)
ls.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.01, max_iter=2000)

# %%
coef=pd.DataFrame(ls.coef_,columns=["weights"])
colmn=pd.DataFrame(X_train.columns,columns=["columns"])
importances=pd.concat([coef,colmn],axis=1)
importances.sort_values("weights",ascending=True,inplace=True)
print(importances)
plt.figure(figsize=(8,6))
plt.barh(importances["columns"],width=importances["weights"])
# Out:
#      weights                     columns
# 21 -0.107310           church_count_5000
# 22 -0.099973          leisure_count_5000
# 9  -0.006584           office_count_5000
# 15 -0.000000   cafe_count_5000_price_500
# 14 -0.000000    cafe_count_5000_na_price
# 13 -0.000000             cafe_count_5000
# 12  0.000000                trc_sqm_5000
# 20 -0.000000  cafe_count_5000_price_high
# 18 -0.000000  cafe_count_5000_price_2500
# 7   0.000000                trc_sqm_3000
# 5  -0.000000             office_sqm_3000
# 3  -0.000000             office_sqm_2000
# 19 -0.000000  cafe_count_5000_price_4000
# 16 -0.000000  cafe_count_5000_price_1000
# 17 -0.000000  cafe_count_5000_price_1500
# 2   0.007582            sport_count_1500
# 6   0.026099              trc_count_3000
# 4   0.032955            sport_count_2000
# 10  0.049128             office_sqm_5000
# 1   0.059996         sport_objects_raion
# 8   0.066972            sport_count_3000
# 23  0.150086            sport_count_5000
# 11  0.157773              trc_count_5000
# 0   0.595158                     full_sq
# <BarContainer object of 24 artists>

# %% [markdown]
# # P-value

# %%
from scipy import stats

# %%
corr_df = pd.DataFrame(columns=["Feature","corr","p_value"])

for col in droped_dataFrame.columns:
    if col == "price_doc":
        break
    else:
        corr,p_value = stats.pearsonr(droped_dataFrame["price_doc"],droped_dataFrame[col])
        corr_df.loc[len(corr_df)] = [col,corr,p_value]
    
corr_df
# Out:
#                        Feature      corr        p_value
# 0                      full_sq  0.586371   0.000000e+00
# 1          sport_objects_raion  0.273112   0.000000e+00
# 2             sport_count_1500  0.277503   0.000000e+00
# 3              office_sqm_2000  0.215977  5.492756e-294
# 4             sport_count_2000  0.302472   0.000000e+00
# 5              office_sqm_3000  0.230154   0.000000e+00
# 6               trc_count_3000  0.297730   0.000000e+00
# 7                 trc_sqm_3000  0.243177   0.000000e+00
# 8             sport_count_3000  0.313842   0.000000e+00
# 9            office_count_5000  0.220170  1.022563e-305
# 10             office_sqm_5000  0.257062   0.000000e+00
# 11              trc_count_5000  0.308243   0.000000e+00
# 12                trc_sqm_5000  0.267961   0.000000e+00
# 13             cafe_count_5000  0.236946   0.000000e+00
# 14    cafe_count_5000_na_price  0.238174   0.000000e+00
# 15   cafe_count_5000_price_500  0.231688   0.000000e+00
# 16  cafe_count_5000_price_1000  0.250835   0.000000e+00
# 17  cafe_count_5000_price_1500  0.239132   0.000000e+00
# 18  cafe_count_5000_price_2500  0.225127  6.637278e-320
# 19  cafe_count_5000_price_4000  0.196389  1.917929e-242
# 20  cafe_count_5000_price_high  0.196917  9.209726e-244
# 21           church_count_5000  0.218499  5.174680e-301
# 22          leisure_count_5000  0.191919  2.009150e-231
# 23            sport_count_5000  0.305924   0.000000e+00

# %% [markdown]
# # Variance Inflation Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = droped_dataFrame.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(droped_dataFrame.values, i)
                          for i in range(len(droped_dataFrame.columns))]

# %%
vif_data
# Out:
#                        feature           VIF
# 0                      full_sq      1.778663
# 1          sport_objects_raion      2.710945
# 2             sport_count_1500      7.716849
# 3              office_sqm_2000     12.855201
# 4             sport_count_2000     16.207849
# 5              office_sqm_3000     26.941806
# 6               trc_count_3000     10.218815
# 7                 trc_sqm_3000      5.932808
# 8             sport_count_3000     19.323430
# 9            office_count_5000    136.844132
# 10             office_sqm_5000     33.132382
# 11              trc_count_5000     22.360496
# 12                trc_sqm_5000      9.192254
# 13             cafe_count_5000  43704.658881
# 14    cafe_count_5000_na_price    268.297481
# 15   cafe_count_5000_price_500   3073.713398
# 16  cafe_count_5000_price_1000   3113.726147
# 17  cafe_count_5000_price_1500   2775.683021
# 18  cafe_count_5000_price_2500   1251.857007
# 19  cafe_count_5000_price_4000    217.179459
# 20  cafe_count_5000_price_high     27.529741
# 21           church_count_5000     39.344766
# 22          leisure_count_5000     40.307340
# 23            sport_count_5000     25.082702
# 24                   price_doc      1.998365

# %%
droped_dataFrame["cafe_count_1000_price_high"].isnull().sum()
